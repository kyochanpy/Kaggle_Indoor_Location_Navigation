# %% [markdown]
# <a href="https://colab.research.google.com/github/kyochanpy/Kaggle_Indoor_Location_Navigation/blob/main/create_dataset/indoor_fixed_train_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -qy kaggle
# !pip install -Uq kaggle
# !apt-get install -y p7zip-full tree
# !mkdir /root/.kaggle
# Out:
#      |████████████████████████████████| 61kB 3.4MB/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (118 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 160980 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# %%writefile /root/.kaggle/kaggle.json
# {"username":"kyochanpy","key":"538b6a6b5a0e28ba6c2fc3c631cb0c3f"}
# Out:
# Writing /root/.kaggle/kaggle.json

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d kyochanpy/indoor-fixed-train-02
# Out:
# ...
# 100% 11.8G/11.8G [01:48<00:00, 107MB/s]
# 100% 11.8G/11.8G [01:48<00:00, 117MB/s]

# %%
# !mkdir /kaggle

# %%
# !unzip -d /kaggle /content/indoor-fixed-train-02.zip
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e38aaec4b20006154bf3.txt
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e38baec4b20006154bf5.txt
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e38c476f600006adcdef.txt
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e38caec4b20006154bf7.txt
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e38daec4b20006154bf9.txt
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e38daec4b20006154bfb.txt
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e38e476f600006adcdf1.txt
#   inflating: /kaggle/content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1/5da7e391aec4b20006154bfd.txt
# ...

# %%
# !mv /kagggle /train

# %%
# !zip archive -r /train
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   adding: train/5d27099f03f801723c32511d/F1/5dce764794e49000061250ee.txt (deflated 80%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce762994e49000061250df.txt (deflated 76%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce76355516ad00065f0366.txt (deflated 77%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce764b94e49000061250f0.txt (deflated 78%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce762c94e49000061250e1.txt (deflated 78%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce763d94e49000061250e6.txt (deflated 77%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce763f94e49000061250e8.txt (deflated 78%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce76495516ad00065f036b.txt (deflated 76%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce764494e49000061250ea.txt (deflated 76%)
#   adding: train/5d27099f03f801723c32511d/F1/5dce764d5516ad00065f036d.txt (deflated 77%)
# ...

# %%
# !mkdir fixed_train_03

# %%
# !mv /content/archive.zip /kaggle
# Out:
# mv: cannot stat '/content/archive.zip': No such file or directory

# %%
# !mv /train /abc

# %%
# !mv /train /fixed_train

# %%
# !mv /fixed_train /xyz

# %%
# !kaggle datasets init -p /xyz
# Out:
# Data package template written to: /xyz/dataset-metadata.json

# %%
# !kaggle datasets create -p /xyz
# Out:
# Starting upload for file fixed_train
# 100% 11.8G/11.8G [02:14<00:00, 93.9MB/s]
# Upload successful: fixed_train (12GB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/kyochanpy/indoor-train-fixed-03
