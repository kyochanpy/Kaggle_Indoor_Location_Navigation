# %% [markdown]
# <a href="https://colab.research.google.com/github/kyochanpy/Kaggle_Indoor_Location_Navigation/blob/main/create_dataset/create_wifi_beacon_for_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# [The result dataset is here.](https://www.kaggle.com/kokitanisaka/unified-ds-wifi-and-beacon)<br>
# <br>
# In this notebook, I show one way to make a dataset, Wi-Fi features and Beacon features. <br>
# And also, I tried to utilize timegap of Wi-Fi and Beacon from the nearest waypoints. <br>
# <br>
# The fundamental idea of this dataset is, make samples based on waypoints. <br>
# So the number of samples is same as number of waypoints. <br>
# Which is much less than [this dataset](https://www.kaggle.com/kokitanisaka/indoorunifiedwifids).<br>
# <br>
# We can have similar result only with Wi-Fi features in [this dataset](https://www.kaggle.com/kokitanisaka/unified-ds-wifi-and-beacon) as [this dataset](https://www.kaggle.com/kokitanisaka/indoorunifiedwifids).<br>
# As it has less samples, the training speed is much faster.<br>
# <br>
# With beacon features, I wasn't able to achieve a better result. <br>
# So if you are interested in it, feel free to do some experiments. <br>
#
# ## Attention
# Not all the samples can have beacon features. Because in some paths, there's no beacon signals are observed.<br>
# we need to take it into account when we train a model. <br>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import glob
import re
import types
import shutil
def imports():
    for name, val in globals().items():
        # module imports
        if isinstance(val, types.ModuleType):
            yield name, val
        # functions / callables
        if hasattr(val, '__call__'):
            yield name, val
np.seterr(divide='ignore', invalid='ignore')
noglobal = lambda fn: types.FunctionType(fn.__code__, dict(imports()))
import multiprocessing
from multiprocessing import Pool

# %%
num_cores = multiprocessing.cpu_count()

base_path = '/content/drive/MyDrive'

# %%
# get target buildings
sample_submission = pd.read_csv(f'{base_path}/sample_submission.csv')
sample_submission = sample_submission["site_path_timestamp"].apply(lambda x: pd.Series(x.split("_")))
sample_submission.columns = ['site', 'path', 'timestamp']
target_buildings = sorted(sample_submission['site'].value_counts().index.tolist())

# %%
# pull out all the buildings actually used in the test set, given current method we don't need the other ones
ssubm = pd.read_csv('/content/drive/MyDrive/sample_submission.csv')

# only 24 of the total buildings are used in the test set, 
# this allows us to greatly reduce the intial size of the dataset

ssubm_df = ssubm["site_path_timestamp"].apply(lambda x: pd.Series(x.split("_")))
used_buildings = sorted(ssubm_df[0].value_counts().index.tolist())

# dictionary used to map the floor codes to the values used in the submission file. 
floor_map = {"B2":-2, "B1":-1, "F1":0, "F2": 1, "F3":2, "F4":3, "F5":4, "F6":5, "F7":6,"F8":7, "F9":8,
             "1F":0, "2F":1, "3F":2, "4F":3, "5F":4, "6F":5, "7F":6, "8F": 7, "9F":8}

# %% [markdown]
# ## Options
# These features determin how to take features from the original txt files.<br>
# <br>
# We take Wi-Fi or beacon features within specific timespan from waypoints. <br>
# I assume that if the time gap is too much, Wi-Fi signals or beacon signals are not trustworthy. <br>
# I set it to 3000ms, but you can try other numbers. <br>
# <br>
# And we can determin how many signals to take into the result dataset. <br>
# Actually beacon doesn't have much samples in the original txt files, or even doesn't have it. <br>
# You can try other numbers as well. <br>

# %%
# options 
NUM_TAKING_BEACONS = 10
NUM_TAKING_WIFIS = 50
TIMEGAP_THRESHOLD = 10 # ms

# %%
# constants
FLOOR_DIR = {"B2": -2, "B1": -1, "F1": 0, "F2": 1, "F3": 2, "F4": 3, "F5": 4, "F6": 5, "F7": 6, "F8": 7, "F9": 8,
             "1F": 0, "2F": 1, "3F": 2, "4F": 3, "5F": 4, "6F": 5, "7F": 6, "8F": 7, "9F": 8}

# %%
# utils
@noglobal
def split_into_each_beacons(s):
    matches = re.finditer("TYPE_BEACON", s)
    matches_positions = [match.start() for match in matches]
    split_idx = [0] + [matches_positions[i]-14 for i in range(1, len(matches_positions))] + [len(s)]
    return [s[split_idx[i]:split_idx[i+1]] for i in range(len(split_idx)-1)]

@noglobal
def extract_waypoint_beacon(path_file):
    TIME = 0

    WAYPOINT_X = 2
    WAYPOINT_Y = 3
    BEACON_DISTANCE = 7
    BEACON_MAC = 8
    
    waypoints = []
    beacons = []
    wifis = []

    with open(path_file, encoding="utf-8") as f:
        text = f.readlines()
        for i, line in enumerate(text):
            type_count = line.count('TYPE_BEACON')
            if type_count > 1:
                lines = split_into_each_beacons(line)
            else:
                lines = [line]

            for l in lines:
                tmp = l.strip().split()
                
                if tmp[1] == "TYPE_WAYPOINT":
                    #1578462618392	TYPE_WAYPOINT	230.03738	153.49635
                    waypoints.append([int(tmp[TIME]), tmp[1], float(tmp[WAYPOINT_X]), float(tmp[WAYPOINT_Y])])

                elif tmp[1] == "TYPE_WIFI":
                    #1578483067644	TYPE_WIFI	da39a3ee5e6b4b0d3255bfef95601890afd80709	2253c6a0d0f7277737aa8e86e0484be805124806	-51	2437	1578483066126
                    try:
                        wifis.append([int(tmp[TIME]), tmp[1], tmp[2], tmp[3], 
                                     int(tmp[4]), int(tmp[5]), int(tmp[6]), 0])
                    except:
                        print(tmp)
                        raise
                    
                elif tmp[1] == "TYPE_BEACON":
                    #1578462618698	TYPE_BEACON	uuid	major	minor	-56	-58	1.2902861669921697	mac	1578462618698, timediff
                    try:
                        if len(tmp) >= 10:                       
                            second_time = tmp[9]
                        else:
                            second_time = tmp[TIME]
                        
                        beacons.append([int(tmp[TIME]), tmp[1], tmp[2], tmp[3], tmp[4], int(tmp[5]), int(tmp[6]), 
                                        float(tmp[BEACON_DISTANCE]), tmp[BEACON_MAC], second_time, 0])
                    except:
                        print(tmp)
                        raise

    return waypoints, sorted(beacons, key=lambda x: float(x[BEACON_DISTANCE])), wifis

@noglobal
def append_timediff(waypoint, beacons, timediffindex=10):
    TIME = 0
    
    to_be_removed = []
    for i, beacon in enumerate(beacons):
        try:
            beacons[i][timediffindex] = abs(waypoint[TIME] - beacon[TIME])
        except:
            to_be_removed.append(i)
            print(f'error:{beacon}')
            raise
    for i in to_be_removed:
        del beacons[i]
        
    return beacons

@noglobal
def make_item_wifi(target_building, floor_val, path_val, waypoint, wifis, TIMEGAP_THRESHOLD, NUM_TAKING_WIFIS):
    WAYPOINT_X = 2
    WAYPOINT_Y = 3

    sorted_by_nearest = [x for x in wifis if x[7] <= TIMEGAP_THRESHOLD]
    sorted_by_nearest = sorted(sorted_by_nearest, key=lambda x: (abs(x[4]), x[7]))[:NUM_TAKING_WIFIS]

    item = [target_building, floor_val, path_val, waypoint[WAYPOINT_X], waypoint[WAYPOINT_Y]]
    for beacon in sorted_by_nearest: 
        item.extend([beacon[3],
                    beacon[4],
                    beacon[7]])

    if len(sorted_by_nearest) < NUM_TAKING_WIFIS:
        for i in range(NUM_TAKING_WIFIS-len(sorted_by_nearest)):
            item.extend(['-', -999, TIMEGAP_THRESHOLD])    

    return item

@noglobal
def append_beacon(target_building, floor_val, path_val, item, waypoint, beacons, TIMEGAP_THRESHOLD, NUM_TAKING_BEACONS):
    BEACON_DISTANCE = 7
    BEACON_MAC = 8
    BEACON_TIMEDIFF = 10
    WAYPOINT_X = 2
    WAYPOINT_Y = 3

    sorted_by_nearest_beacons = [x for x in beacons if x[BEACON_TIMEDIFF] <= TIMEGAP_THRESHOLD]
    sorted_by_nearest_beacons = sorted(sorted_by_nearest_beacons, key=lambda x: x[BEACON_DISTANCE])[:NUM_TAKING_BEACONS]

    #item = [target_building, floor_val, path_val, waypoint[WAYPOINT_X], waypoint[WAYPOINT_Y]]
    for beacon in sorted_by_nearest_beacons: # select from the nearest beacons
        item.extend([beacon[BEACON_MAC],
                    beacon[BEACON_DISTANCE],
                    beacon[BEACON_TIMEDIFF]])

    if len(sorted_by_nearest_beacons) < NUM_TAKING_BEACONS:
        for i in range(NUM_TAKING_BEACONS-len(sorted_by_nearest_beacons)):
            item.extend(['-', -99, TIMEGAP_THRESHOLD])

    return item

@noglobal
def yield_columns(NUM_TAKING_WIFIS, NUM_TAKING_BEACONS):
    columns = []
    for i in range(NUM_TAKING_WIFIS):
        columns.append(f'wifi_bssid_{i}')
        columns.append(f'wifi_rssi_{i}')
        columns.append(f'wifi_timegap_{i}')

    for i in range(NUM_TAKING_BEACONS):
        columns.append(f'beacon_macaddress_{i}')
        columns.append(f'beacon_distance_{i}')
        columns.append(f'beacon_timegap_{i}')

    return columns

# %%
def create_data_per_building(target_building):
    floors = sorted(glob.glob(f'{base_path}/fixed_train/train/{target_building}/*'))
    
    items = []
    
    for floor in floors:
        print(floor)
        
        floor_val = floor.split('/')[-1]
        floor_val = FLOOR_DIR[floor_val]
        
        paths = sorted(glob.glob(f'{floor}/*.txt'))
        
        for path_file in paths:
            path_val = path_file.split('/')[-1].replace('.txt', '')
            
            waypoints, beacons, wifis = extract_waypoint_beacon(path_file)

            for waypoint in waypoints:
                wifis = append_timediff(waypoint, wifis, 7)
                beacons = append_timediff(waypoint, beacons, 10)
                
                item = make_item_wifi(target_building, floor_val, path_val, waypoint, wifis, TIMEGAP_THRESHOLD, NUM_TAKING_WIFIS)
                item = append_beacon(target_building, floor_val, path_val, item, waypoint, beacons, TIMEGAP_THRESHOLD, NUM_TAKING_BEACONS)
            
                items.append(item)
                
                
    items = pd.DataFrame(items, columns=['site', 'floor', 'path', 'x', 'y'] + yield_columns(NUM_TAKING_WIFIS, NUM_TAKING_BEACONS))
    train_all_list.append(items)
    items.to_csv(f'{target_building}_train.csv')
    shutil.move(f'{target_building}_train.csv', '/content/drive/MyDrive/nn_wifi_50_beacon_10_10')

# %%
train_all_list = []

# %%
# make files for train set
with Pool(num_cores) as pool:
    pool.map(create_data_per_building, [t for t in target_buildings])
# Out:
# /content/drive/MyDrive/fixed_train/train/5a0546857ecc773753327266/B1
# /content/drive/MyDrive/fixed_train/train/5d27096c03f801723c31e5e0/B1
# /content/drive/MyDrive/fixed_train/train/5d27096c03f801723c31e5e0/F1
# /content/drive/MyDrive/fixed_train/train/5a0546857ecc773753327266/F1
# /content/drive/MyDrive/fixed_train/train/5d27096c03f801723c31e5e0/F2
# /content/drive/MyDrive/fixed_train/train/5d27096c03f801723c31e5e0/F3
# /content/drive/MyDrive/fixed_train/train/5a0546857ecc773753327266/F2
# /content/drive/MyDrive/fixed_train/train/5d27096c03f801723c31e5e0/F4
# /content/drive/MyDrive/fixed_train/train/5d27096c03f801723c31e5e0/F5
# /content/drive/MyDrive/fixed_train/train/5d27096c03f801723c31e5e0/F6
# /content/drive/MyDrive/fixed_train/train/5a0546857ecc773753327266/F3
# /content/drive/MyDrive/fixed_train/train/5d27097f03f801723c320d97/B1
# /content/drive/MyDrive/fixed_train/train/5d27097f03f801723c320d97/B2
# /content/drive/MyDrive/fixed_train/train/5d27097f03f801723c320d97/F1
# /content/drive/MyDrive/fixed_train/train/5a0546857ecc773753327266/F4
# /content/drive/MyDrive/fixed_train/train/5d27097f03f801723c320d97/F2
# /content/drive/MyDrive/fixed_train/train/5c3c44b80379370013e0fd2b/B1
# /content/drive/MyDrive/fixed_train/train/5d27097f03f801723c320d97/F3
# /content/drive/MyDrive/fixed_train/train/5c3c44b80379370013e0fd2b/F1
# /content/drive/MyDrive/fixed_train/train/5d27097f03f801723c320d97/F4
# /content/drive/MyDrive/fixed_train/train/5d27097f03f801723c320d97/F5
# /content/drive/MyDrive/fixed_train/train/5c3c44b80379370013e0fd2b/F2
# /content/drive/MyDrive/fixed_train/train/5d27099f03f801723c32511d/B1
# /content/drive/MyDrive/fixed_train/train/5d27099f03f801723c32511d/F1
# /content/drive/MyDrive/fixed_train/train/5d27099f03f801723c32511d/F2
# /content/drive/MyDrive/fixed_train/train/5c3c44b80379370013e0fd2b/F3
# /content/drive/MyDrive/fixed_train/train/5c3c44b80379370013e0fd2b/F4
# /content/drive/MyDrive/fixed_train/train/5d27099f03f801723c32511d/F3
# /content/drive/MyDrive/fixed_train/train/5d27099f03f801723c32511d/F4
# /content/drive/MyDrive/fixed_train/train/5c3c44b80379370013e0fd2b/F5
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/B1
# /content/drive/MyDrive/fixed_train/train/5d2709a003f801723c3251bf/1F
# /content/drive/MyDrive/fixed_train/train/5d2709a003f801723c3251bf/2F
# /content/drive/MyDrive/fixed_train/train/5d2709a003f801723c3251bf/3F
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/F1
# /content/drive/MyDrive/fixed_train/train/5d2709a003f801723c3251bf/4F
# /content/drive/MyDrive/fixed_train/train/5d2709b303f801723c327472/1F
# /content/drive/MyDrive/fixed_train/train/5d2709b303f801723c327472/2F
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/F2
# /content/drive/MyDrive/fixed_train/train/5d2709b303f801723c327472/3F
# /content/drive/MyDrive/fixed_train/train/5d2709b303f801723c327472/4F
# /content/drive/MyDrive/fixed_train/train/5d2709b303f801723c327472/B1
# /content/drive/MyDrive/fixed_train/train/5d2709bb03f801723c32852c/B1
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/F3
# /content/drive/MyDrive/fixed_train/train/5d2709bb03f801723c32852c/F1
# /content/drive/MyDrive/fixed_train/train/5d2709bb03f801723c32852c/F2
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/F4
# /content/drive/MyDrive/fixed_train/train/5d2709bb03f801723c32852c/F3
# /content/drive/MyDrive/fixed_train/train/5d2709bb03f801723c32852c/F4
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/1F
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/F5
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/F6
# /content/drive/MyDrive/fixed_train/train/5d27075f03f801723c2e360f/F7
# /content/drive/MyDrive/fixed_train/train/5da138274db8ce0c98bbd3d2/F1
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/2F
# /content/drive/MyDrive/fixed_train/train/5da138274db8ce0c98bbd3d2/F2
# /content/drive/MyDrive/fixed_train/train/5da138274db8ce0c98bbd3d2/F3
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/3F
# /content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/B1
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/4F
# /content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F1
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/5F
# /content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F2
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/6F
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/7F
# /content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F3
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/8F
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/9F
# /content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F4
# /content/drive/MyDrive/fixed_train/train/5d2709c303f801723c3299ee/B1
# /content/drive/MyDrive/fixed_train/train/5d2709d403f801723c32bd39/1F
# /content/drive/MyDrive/fixed_train/train/5da1382d4db8ce0c98bbe92e/F5
# /content/drive/MyDrive/fixed_train/train/5da138314db8ce0c98bbf3a0/B1
# /content/drive/MyDrive/fixed_train/train/5d2709d403f801723c32bd39/2F
# /content/drive/MyDrive/fixed_train/train/5d2709d403f801723c32bd39/3F
# /content/drive/MyDrive/fixed_train/train/5da138314db8ce0c98bbf3a0/B2
# /content/drive/MyDrive/fixed_train/train/5d2709d403f801723c32bd39/B1
# /content/drive/MyDrive/fixed_train/train/5da138314db8ce0c98bbf3a0/F1
# /content/drive/MyDrive/fixed_train/train/5d2709e003f801723c32d896/B1
# /content/drive/MyDrive/fixed_train/train/5da138314db8ce0c98bbf3a0/F2
# /content/drive/MyDrive/fixed_train/train/5da138314db8ce0c98bbf3a0/F3
# /content/drive/MyDrive/fixed_train/train/5d2709e003f801723c32d896/F1
# /content/drive/MyDrive/fixed_train/train/5da138364db8ce0c98bc00f1/F1
# /content/drive/MyDrive/fixed_train/train/5d2709e003f801723c32d896/F2
# /content/drive/MyDrive/fixed_train/train/5da138364db8ce0c98bc00f1/F2
# /content/drive/MyDrive/fixed_train/train/5d2709e003f801723c32d896/F3
# /content/drive/MyDrive/fixed_train/train/5da138364db8ce0c98bc00f1/F3
# /content/drive/MyDrive/fixed_train/train/5da1383b4db8ce0c98bc11ab/F1
# /content/drive/MyDrive/fixed_train/train/5d2709e003f801723c32d896/F4
# /content/drive/MyDrive/fixed_train/train/5d2709e003f801723c32d896/F5
# /content/drive/MyDrive/fixed_train/train/5da1383b4db8ce0c98bc11ab/F2
# /content/drive/MyDrive/fixed_train/train/5da138764db8ce0c98bcaa46/B1
# /content/drive/MyDrive/fixed_train/train/5da138764db8ce0c98bcaa46/F1
# /content/drive/MyDrive/fixed_train/train/5da1383b4db8ce0c98bc11ab/F3
# /content/drive/MyDrive/fixed_train/train/5da138764db8ce0c98bcaa46/F2
# /content/drive/MyDrive/fixed_train/train/5da138754db8ce0c98bca82f/F1
# /content/drive/MyDrive/fixed_train/train/5da138754db8ce0c98bca82f/F2
# /content/drive/MyDrive/fixed_train/train/5da138764db8ce0c98bcaa46/F3
# /content/drive/MyDrive/fixed_train/train/5da138754db8ce0c98bca82f/F3
# /content/drive/MyDrive/fixed_train/train/5da138754db8ce0c98bca82f/F4
# /content/drive/MyDrive/fixed_train/train/5da138764db8ce0c98bcaa46/F4
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/B1
# /content/drive/MyDrive/fixed_train/train/5da138764db8ce0c98bcaa46/F5
# /content/drive/MyDrive/fixed_train/train/5da1389e4db8ce0c98bd0547/B1
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/F1
# /content/drive/MyDrive/fixed_train/train/5da1389e4db8ce0c98bd0547/B2
# /content/drive/MyDrive/fixed_train/train/5da1389e4db8ce0c98bd0547/F1
# /content/drive/MyDrive/fixed_train/train/5da1389e4db8ce0c98bd0547/F2
# /content/drive/MyDrive/fixed_train/train/5da1389e4db8ce0c98bd0547/F3
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/F2
# /content/drive/MyDrive/fixed_train/train/5da1389e4db8ce0c98bd0547/F4
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/F3
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/F4
# /content/drive/MyDrive/fixed_train/train/5da138b74db8ce0c98bd4774/B1
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/F5
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/F6
# /content/drive/MyDrive/fixed_train/train/5da958dd46f8266d0737457b/F7
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/B1
# /content/drive/MyDrive/fixed_train/train/5da138b74db8ce0c98bd4774/B2
# /content/drive/MyDrive/fixed_train/train/5da138b74db8ce0c98bd4774/F1
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/F2
# /content/drive/MyDrive/fixed_train/train/5da138b74db8ce0c98bd4774/F2
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/F3
# /content/drive/MyDrive/fixed_train/train/5da138b74db8ce0c98bd4774/F3
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/F4
# /content/drive/MyDrive/fixed_train/train/5da138b74db8ce0c98bd4774/F4
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/F5
# /content/drive/MyDrive/fixed_train/train/5da138b74db8ce0c98bd4774/F5
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/F6
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/F7
# /content/drive/MyDrive/fixed_train/train/5dbc1d84c1eb61796cf7c010/F8
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/B1
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/F1
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/F2
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/F3
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/F4
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/F5
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/F6
# /content/drive/MyDrive/fixed_train/train/5dc8cea7659e181adb076a3f/F7

# %%
train_all_list = []
for building in used_buildings:
    df = pd.read_csv(f'/content/drive/MyDrive/nn_wifi_50_beacon_10_10/{building}_train.csv')
    train_all_list.append(df)

# %%
train_all = pd.concat(train_all_list)
train_all.to_pickle('train_all.pkl')
shutil.move('train_all.pkl', '/content/drive/MyDrive/nn_wifi_50_beacon_10_10')
# Out:
# '/content/drive/MyDrive/nn_wifi_50_beacon_10_10/train_all.pkl'

# %%
# make file for test set

paths = sorted(glob.glob(f'{base_path}/fixed_train/test/*'))

items = []

for i, path_file in enumerate(paths):
    path_val = path_file.split('/')[-1].replace('.txt', '')

    print(f'{i}:{path_file}')
    
    _, beacons, wifis = extract_waypoint_beacon(path_file)

    targets = sample_submission[sample_submission['path'] == path_val]
    targets['timestamp'] = targets['timestamp'].astype(int)
    targets.loc[:,'type'] = 'TYPE_WAYPOINT'
    targets.loc[:,'x'] = 0
    targets.loc[:,'y'] = 0
    waypoints_to_predict = targets[['timestamp', 'type', 'x', 'y']].values.tolist()

    target_building = targets.iloc[0, 0]
    
    for waypoint in waypoints_to_predict:
        wifis = append_timediff(waypoint, wifis, 7)
        beacons = append_timediff(waypoint, beacons, 10)

        timed = [str(waypoint[0]).zfill(13)]
        item = make_item_wifi(target_building, 0, path_val, waypoint, wifis, TIMEGAP_THRESHOLD, NUM_TAKING_WIFIS)
        timed.extend(item)
        timed = append_beacon(target_building, 0, path_val, timed, waypoint, beacons, TIMEGAP_THRESHOLD, NUM_TAKING_BEACONS)
        
        items.append(timed)

items = pd.DataFrame(items, columns=['timestamp', 'site', 'floor', 'path', 'x', 'y'] + yield_columns(NUM_TAKING_WIFIS, NUM_TAKING_BEACONS))

items.to_csv(f'test.csv')
# Out:
# 0:/content/drive/MyDrive/fixed_train/test/00ff0c9a71cc37a2ebdd0f05.txt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# 1:/content/drive/MyDrive/fixed_train/test/01c41f1aeba5c48c2c4dd568.txt
# 2:/content/drive/MyDrive/fixed_train/test/030b3d94de8acae7c936563d.txt
# 3:/content/drive/MyDrive/fixed_train/test/0389421238a7e2839701df0f.txt
# 4:/content/drive/MyDrive/fixed_train/test/04029880763600640a0cf42c.txt
# 5:/content/drive/MyDrive/fixed_train/test/0412d582bb8a2c89400a1ffb.txt
# 6:/content/drive/MyDrive/fixed_train/test/046cfa46be49fc10834815c6.txt
# 7:/content/drive/MyDrive/fixed_train/test/049bb468e7e166e9d6370002.txt
# 8:/content/drive/MyDrive/fixed_train/test/04b259d70f2b503f2af14c35.txt
# 9:/content/drive/MyDrive/fixed_train/test/053526f9012ca715313120cd.txt
# 10:/content/drive/MyDrive/fixed_train/test/055255f16b549ed22893c0c3.txt
# 11:/content/drive/MyDrive/fixed_train/test/05a6d4cdf3d1eb9b5671f71b.txt
# 12:/content/drive/MyDrive/fixed_train/test/05d052dde78384b0c543d89c.txt
# 13:/content/drive/MyDrive/fixed_train/test/06832e9b9ca24ff7fe906aee.txt
# 14:/content/drive/MyDrive/fixed_train/test/06882da3694b7160c0f105f5.txt
# 15:/content/drive/MyDrive/fixed_train/test/068e4f6926e78ff6d338d2cc.txt
# 16:/content/drive/MyDrive/fixed_train/test/07db4eec1fc8df5040d86602.txt
# 17:/content/drive/MyDrive/fixed_train/test/07fa2d05e9b5a9841b7bfae3.txt
# 18:/content/drive/MyDrive/fixed_train/test/085e9207300765e045a942bf.txt
# 19:/content/drive/MyDrive/fixed_train/test/0884650b5640ded8c63750fc.txt
# 20:/content/drive/MyDrive/fixed_train/test/08a29ac71fe460a44ca73b38.txt
# 21:/content/drive/MyDrive/fixed_train/test/0969b6db91bb1697f99a8a21.txt
# 22:/content/drive/MyDrive/fixed_train/test/0a5c442ffa2664e89e18262d.txt
# 23:/content/drive/MyDrive/fixed_train/test/0ab1b38a35a76b0e5bf2ca8d.txt
# 24:/content/drive/MyDrive/fixed_train/test/0b6e7a34b2a1b99280b5d3ca.txt
# 25:/content/drive/MyDrive/fixed_train/test/0c06cc9f21d172618d74c6c8.txt
# 26:/content/drive/MyDrive/fixed_train/test/0ce9bd5bf8f2351bfd217774.txt
# 27:/content/drive/MyDrive/fixed_train/test/0d08327383a1f146a26a2a2b.txt
# 28:/content/drive/MyDrive/fixed_train/test/0d4d75060f346ce93d416d01.txt
# 29:/content/drive/MyDrive/fixed_train/test/0dbf956c380feddc590348e0.txt
# 30:/content/drive/MyDrive/fixed_train/test/0df4917338687fdbc93448f5.txt
# 31:/content/drive/MyDrive/fixed_train/test/0eeb9f6b6d4c8f39fb34b577.txt
# 32:/content/drive/MyDrive/fixed_train/test/0fb75bf676e1cddace3590d5.txt
# 33:/content/drive/MyDrive/fixed_train/test/0fee6e9fd162d281b15c11df.txt
# 34:/content/drive/MyDrive/fixed_train/test/108d983b84def2bd48bdca36.txt
# 35:/content/drive/MyDrive/fixed_train/test/10f9407023d1e00bbd7274f2.txt
# 36:/content/drive/MyDrive/fixed_train/test/110637c78f384710d1b3eba6.txt
# 37:/content/drive/MyDrive/fixed_train/test/136d1cb5b01538b9979aedbe.txt
# 38:/content/drive/MyDrive/fixed_train/test/13d970ab11b767d7ae3e4ee6.txt
# 39:/content/drive/MyDrive/fixed_train/test/13ed7262c2b6088cd47de5ed.txt
# 40:/content/drive/MyDrive/fixed_train/test/146035943a1482883ed98570.txt
# 41:/content/drive/MyDrive/fixed_train/test/14669681607aa88e65b0d927.txt
# 42:/content/drive/MyDrive/fixed_train/test/14f45baa63b4d3a700126af6.txt
# 43:/content/drive/MyDrive/fixed_train/test/15a04a78926385821aa96a62.txt
# 44:/content/drive/MyDrive/fixed_train/test/15d9cd90a0c1d8c0b2e060f8.txt
# 45:/content/drive/MyDrive/fixed_train/test/167fd824f8c93490e4714032.txt
# 46:/content/drive/MyDrive/fixed_train/test/16e7537d3cb1b1b206cf08a8.txt
# 47:/content/drive/MyDrive/fixed_train/test/1747b3e80ba80910158c0cef.txt
# 48:/content/drive/MyDrive/fixed_train/test/17540fdca1dd0b3d5620336d.txt
# 49:/content/drive/MyDrive/fixed_train/test/178d893e0fd1457ad7fdadd6.txt
# 50:/content/drive/MyDrive/fixed_train/test/1892ff54553115169341d72e.txt
# 51:/content/drive/MyDrive/fixed_train/test/18ab7e85351d03d1cd691a73.txt
# 52:/content/drive/MyDrive/fixed_train/test/19bf3d9c5236d0f7429baa6a.txt
# 53:/content/drive/MyDrive/fixed_train/test/19e4a759bff01332b4216bda.txt
# 54:/content/drive/MyDrive/fixed_train/test/19ea02c9635f48c2bc7a161f.txt
# 55:/content/drive/MyDrive/fixed_train/test/1a2cc4c5793fa089dd58ddd1.txt
# 56:/content/drive/MyDrive/fixed_train/test/1ab6361c3c5a94fc99e7ae68.txt
# 57:/content/drive/MyDrive/fixed_train/test/1b9fb13726d1030612228aeb.txt
# 58:/content/drive/MyDrive/fixed_train/test/1c93cbfe9be665edd768737d.txt
# 59:/content/drive/MyDrive/fixed_train/test/1c99e4c566466c0d82fc2d6c.txt
# 60:/content/drive/MyDrive/fixed_train/test/1d811352eaf5a17cf918d3dd.txt
# 61:/content/drive/MyDrive/fixed_train/test/1e85728385bc83e6bb650798.txt
# 62:/content/drive/MyDrive/fixed_train/test/1ef2771dfea25d508142ba06.txt
# 63:/content/drive/MyDrive/fixed_train/test/20073e2d139310a2bae877c4.txt
# 64:/content/drive/MyDrive/fixed_train/test/2116a2a90f494f7773b550ef.txt
# 65:/content/drive/MyDrive/fixed_train/test/21459c30ba2ac052fed92f25.txt
# 66:/content/drive/MyDrive/fixed_train/test/2148b02cde5342187216fa75.txt
# 67:/content/drive/MyDrive/fixed_train/test/219d400e61f8e06a066572f8.txt
# 68:/content/drive/MyDrive/fixed_train/test/227b32473aa440c6497e2ae9.txt
# 69:/content/drive/MyDrive/fixed_train/test/236bb7800311ca69deeb0a16.txt
# 70:/content/drive/MyDrive/fixed_train/test/2379a535c2221d54e8caf6ff.txt
# 71:/content/drive/MyDrive/fixed_train/test/238a279ef92528dd92aeb2e3.txt
# 72:/content/drive/MyDrive/fixed_train/test/23b4c8eb4b41d75946285461.txt
# 73:/content/drive/MyDrive/fixed_train/test/240060212e4ee62beb701c5c.txt
# 74:/content/drive/MyDrive/fixed_train/test/2402c2005e29469cbfbf410b.txt
# 75:/content/drive/MyDrive/fixed_train/test/242c6ee1e520eff5ef06a45d.txt
# 76:/content/drive/MyDrive/fixed_train/test/244c21fb418ea7e21425abde.txt
# 77:/content/drive/MyDrive/fixed_train/test/24d83dcc0488f735862e4d3d.txt
# 78:/content/drive/MyDrive/fixed_train/test/24fca45b67e543a4ad737709.txt
# 79:/content/drive/MyDrive/fixed_train/test/25a8bb2034f511717c46e536.txt
# 80:/content/drive/MyDrive/fixed_train/test/2658f7f85981f264dd9657f0.txt
# 81:/content/drive/MyDrive/fixed_train/test/2670249c99fdb6bba41a8511.txt
# 82:/content/drive/MyDrive/fixed_train/test/26c2e2bc3d0f36109337b502.txt
# 83:/content/drive/MyDrive/fixed_train/test/270a66500675e14fb3154c63.txt
# 84:/content/drive/MyDrive/fixed_train/test/291ca2c9bd7d29242b483157.txt
# 85:/content/drive/MyDrive/fixed_train/test/29579192e65ea7826a727c42.txt
# 86:/content/drive/MyDrive/fixed_train/test/29781f56d67d950acd783d29.txt
# 87:/content/drive/MyDrive/fixed_train/test/2a39636327b1f42f80bb08cd.txt
# 88:/content/drive/MyDrive/fixed_train/test/2a83a489565dfa1d77af9f51.txt
# 89:/content/drive/MyDrive/fixed_train/test/2ad9c59e934facf0b0245af3.txt
# 90:/content/drive/MyDrive/fixed_train/test/2ae8bd41bbf2eb78d76d737d.txt
# 91:/content/drive/MyDrive/fixed_train/test/2b4bacedc942ffcb523ff20f.txt
# 92:/content/drive/MyDrive/fixed_train/test/2b9462352bb399a34091d861.txt
# 93:/content/drive/MyDrive/fixed_train/test/2bb6f7e32d3191326d674809.txt
# 94:/content/drive/MyDrive/fixed_train/test/2bc46d57dc3f3ba0480e9f08.txt
# 95:/content/drive/MyDrive/fixed_train/test/2bdf91b83e265e197ac7b117.txt
# 96:/content/drive/MyDrive/fixed_train/test/2bf1ea3f5895fbdadd5b4a74.txt
# 97:/content/drive/MyDrive/fixed_train/test/2c5da83393691efba7f8da42.txt
# 98:/content/drive/MyDrive/fixed_train/test/2d17cc2d5c1660c51e00d505.txt
# 99:/content/drive/MyDrive/fixed_train/test/2db317d8880522bb060d0819.txt
# 100:/content/drive/MyDrive/fixed_train/test/2de4f5fea373eb7b69a84824.txt
# 101:/content/drive/MyDrive/fixed_train/test/2e343fa6a9237d61d0f99ccc.txt
# 102:/content/drive/MyDrive/fixed_train/test/2edd1ed9897871186b126a68.txt
# 103:/content/drive/MyDrive/fixed_train/test/2f33560940ba465c8226c951.txt
# 104:/content/drive/MyDrive/fixed_train/test/2fe9bdaed4fb3e1368e07ccc.txt
# 105:/content/drive/MyDrive/fixed_train/test/2fed60cb00f71d86ef78b5b4.txt
# 106:/content/drive/MyDrive/fixed_train/test/2ff4941b091ecb02e41997cd.txt
# 107:/content/drive/MyDrive/fixed_train/test/309c38eba30007e666cf7fd0.txt
# 108:/content/drive/MyDrive/fixed_train/test/30ed8393bd1d301cd380c06b.txt
# 109:/content/drive/MyDrive/fixed_train/test/310990c10f799a9b21cd4ff3.txt
# 110:/content/drive/MyDrive/fixed_train/test/32bcee0203f7d0cac3ed504b.txt
# 111:/content/drive/MyDrive/fixed_train/test/32e88857b1938abaebce9a76.txt
# 112:/content/drive/MyDrive/fixed_train/test/330b81185e5f5c5513ae7d2f.txt
# 113:/content/drive/MyDrive/fixed_train/test/340f3ca472a404fbef58f8b1.txt
# 114:/content/drive/MyDrive/fixed_train/test/346bf8f7f1c62bcb4cd6e307.txt
# 115:/content/drive/MyDrive/fixed_train/test/34bb5da757c9c83b42e5ae63.txt
# 116:/content/drive/MyDrive/fixed_train/test/3506b3b626f494b0f0b934ca.txt
# 117:/content/drive/MyDrive/fixed_train/test/35b801b06a7816dc8a77080c.txt
# 118:/content/drive/MyDrive/fixed_train/test/35b82be00f77fc7f1d241575.txt
# 119:/content/drive/MyDrive/fixed_train/test/36481f178c4ce333acccd58e.txt
# 120:/content/drive/MyDrive/fixed_train/test/36b20f235015f30bcd123c86.txt
# 121:/content/drive/MyDrive/fixed_train/test/36c6dd1ccc482e94fa21830c.txt
# 122:/content/drive/MyDrive/fixed_train/test/36e11c56d336fd708d34ac37.txt
# 123:/content/drive/MyDrive/fixed_train/test/3843f1ee3f43653993d60447.txt
# 124:/content/drive/MyDrive/fixed_train/test/38876a9e9fee20526c6890bf.txt
# 125:/content/drive/MyDrive/fixed_train/test/39537bf344b43f10a20e060f.txt
# 126:/content/drive/MyDrive/fixed_train/test/39a5e60107bdf4c530130c52.txt
# 127:/content/drive/MyDrive/fixed_train/test/39cd26c8eec1b8a14a561b28.txt
# 128:/content/drive/MyDrive/fixed_train/test/3a893f2b18e85ef08567debf.txt
# 129:/content/drive/MyDrive/fixed_train/test/3aac7e63e395fe2902ce9bd9.txt
# 130:/content/drive/MyDrive/fixed_train/test/3bc2ad10daefe7fc6e57bdca.txt
# 131:/content/drive/MyDrive/fixed_train/test/3c0ebe929de57c5b1fc65d44.txt
# 132:/content/drive/MyDrive/fixed_train/test/3c56892f6cd0af56fe6b92e0.txt
# 133:/content/drive/MyDrive/fixed_train/test/3c612b99b0f6800992eacf43.txt
# 134:/content/drive/MyDrive/fixed_train/test/3c972e7cbba71d1c684dd34f.txt
# 135:/content/drive/MyDrive/fixed_train/test/3ca3e65a5fc44603f0c827ba.txt
# 136:/content/drive/MyDrive/fixed_train/test/3dbf5c79cfcc18eaca1a7d3b.txt
# 137:/content/drive/MyDrive/fixed_train/test/3e0aebb66ef39150bbc27c24.txt
# 138:/content/drive/MyDrive/fixed_train/test/3e1ba2182d077b7fd17d524f.txt
# 139:/content/drive/MyDrive/fixed_train/test/3e1d46017fbfcc8136bd1e9b.txt
# 140:/content/drive/MyDrive/fixed_train/test/3e61e72b06bc6f787d9b176f.txt
# 141:/content/drive/MyDrive/fixed_train/test/3e6892787428117fb4b061d7.txt
# 142:/content/drive/MyDrive/fixed_train/test/3edd7d06006a5bfc1619fc0e.txt
# 143:/content/drive/MyDrive/fixed_train/test/3f815bfeee94086f60be0d09.txt
# 144:/content/drive/MyDrive/fixed_train/test/3fc0e68775cde4a5fce6cf2d.txt
# 145:/content/drive/MyDrive/fixed_train/test/40268946c8060c91109a58b7.txt
# 146:/content/drive/MyDrive/fixed_train/test/408e9eacfcb439043f4ce593.txt
# 147:/content/drive/MyDrive/fixed_train/test/40ded46d0cb2e060306b26bb.txt
# 148:/content/drive/MyDrive/fixed_train/test/412da1891c4780f6f0f7f4bc.txt
# 149:/content/drive/MyDrive/fixed_train/test/41451a862cca51c9df6bf152.txt
# 150:/content/drive/MyDrive/fixed_train/test/41fb71519f03dabae411b661.txt
# 151:/content/drive/MyDrive/fixed_train/test/4209447de426d0c86761703a.txt
# 152:/content/drive/MyDrive/fixed_train/test/4283389c88821c3b31d07df5.txt
# 153:/content/drive/MyDrive/fixed_train/test/4339bf75463dd4e25aa84758.txt
# 154:/content/drive/MyDrive/fixed_train/test/438a576003e0eef20daf9c35.txt
# 155:/content/drive/MyDrive/fixed_train/test/43b5cb4125a03434d3ee065d.txt
# 156:/content/drive/MyDrive/fixed_train/test/44167d3f37c95565f14a5ef4.txt
# 157:/content/drive/MyDrive/fixed_train/test/446d199192f9d69464b77ffd.txt
# 158:/content/drive/MyDrive/fixed_train/test/44bb4250c66f06bffc554828.txt
# 159:/content/drive/MyDrive/fixed_train/test/44bc288dc5e6d7b2819f88c5.txt
# 160:/content/drive/MyDrive/fixed_train/test/4573afa8da16a43e0e2a355f.txt
# 161:/content/drive/MyDrive/fixed_train/test/4690d48f649624bdf8a09b1b.txt
# 162:/content/drive/MyDrive/fixed_train/test/46c865d487fa011022507710.txt
# 163:/content/drive/MyDrive/fixed_train/test/472be94f5be907c04c932114.txt
# 164:/content/drive/MyDrive/fixed_train/test/47a960ef9f70f0b662d9d244.txt
# 165:/content/drive/MyDrive/fixed_train/test/47b83323569055e31d15a469.txt
# 166:/content/drive/MyDrive/fixed_train/test/48dbda4179aaef31ed33c6e4.txt
# 167:/content/drive/MyDrive/fixed_train/test/491066b9356a9f968e04b09b.txt
# 168:/content/drive/MyDrive/fixed_train/test/49ef0e8c42428f0c67c3ed4b.txt
# 169:/content/drive/MyDrive/fixed_train/test/4aaa69d3ff7e13ed5e824aa2.txt
# 170:/content/drive/MyDrive/fixed_train/test/4affd104e0ec7a7806edfa78.txt
# 171:/content/drive/MyDrive/fixed_train/test/4b38e02c59253ce02b52eec5.txt
# 172:/content/drive/MyDrive/fixed_train/test/4b3c36b97204adfe690ccb00.txt
# 173:/content/drive/MyDrive/fixed_train/test/4b8d3aff14914537854587c1.txt
# 174:/content/drive/MyDrive/fixed_train/test/4c93f4e157d7e283547f1153.txt
# 175:/content/drive/MyDrive/fixed_train/test/4d4315146c8acfc8f7a20550.txt
# 176:/content/drive/MyDrive/fixed_train/test/4d497d31be6d37d79186717e.txt
# 177:/content/drive/MyDrive/fixed_train/test/4d51d8913e1c785e0a1dddef.txt
# 178:/content/drive/MyDrive/fixed_train/test/4dcb3e9d10defbea8e8007c2.txt
# 179:/content/drive/MyDrive/fixed_train/test/4df1cce533e2aaf6882fb638.txt
# 180:/content/drive/MyDrive/fixed_train/test/4e2aedb331c566b0e7684ffc.txt
# 181:/content/drive/MyDrive/fixed_train/test/4e7665b783a3113c7e73cb94.txt
# 182:/content/drive/MyDrive/fixed_train/test/4efb8bc8c17cfc5d9cd71c7f.txt
# 183:/content/drive/MyDrive/fixed_train/test/4f66cef6a69aaf88468f7ab7.txt
# 184:/content/drive/MyDrive/fixed_train/test/4fbd93217986b45372ebedd4.txt
# 185:/content/drive/MyDrive/fixed_train/test/4ff5b9152353b3dc458992fa.txt
# 186:/content/drive/MyDrive/fixed_train/test/4ff6a5f94782360efff2c334.txt
# 187:/content/drive/MyDrive/fixed_train/test/500913fc93d997b6803dd6df.txt
# 188:/content/drive/MyDrive/fixed_train/test/504b8655852f837f2aca36a7.txt
# 189:/content/drive/MyDrive/fixed_train/test/505a039e760d4875c9c2d77f.txt
# 190:/content/drive/MyDrive/fixed_train/test/507749a1187be5b582671c62.txt
# 191:/content/drive/MyDrive/fixed_train/test/50b0a8d77c8c34368ea4bfc7.txt
# 192:/content/drive/MyDrive/fixed_train/test/50dfc9af184b9f9e05ef1ae2.txt
# 193:/content/drive/MyDrive/fixed_train/test/50f24c8ed539bdc44ebf1dd8.txt
# 194:/content/drive/MyDrive/fixed_train/test/52265eb3084b4e3f7b08f6ae.txt
# 195:/content/drive/MyDrive/fixed_train/test/5243b058c6691779fae7da2c.txt
# 196:/content/drive/MyDrive/fixed_train/test/5258ce6a8b63b1f30d04a2d5.txt
# 197:/content/drive/MyDrive/fixed_train/test/52ad8c760ff9978d0949deed.txt
# 198:/content/drive/MyDrive/fixed_train/test/52dc57274881463626784b21.txt
# 199:/content/drive/MyDrive/fixed_train/test/5340e354629f97c9348270c0.txt
# 200:/content/drive/MyDrive/fixed_train/test/536134a5924bfa7840e315de.txt
# 201:/content/drive/MyDrive/fixed_train/test/536f7b36d89b921511f4fdc1.txt
# 202:/content/drive/MyDrive/fixed_train/test/54b4ec188d91140a6a2ee030.txt
# 203:/content/drive/MyDrive/fixed_train/test/5582270fcaee1f580de9006f.txt
# 204:/content/drive/MyDrive/fixed_train/test/559b85f5e7c3de56619c8853.txt
# 205:/content/drive/MyDrive/fixed_train/test/5694e13f4bb0bac39806b5ae.txt
# 206:/content/drive/MyDrive/fixed_train/test/5697db90a6c6bcb3e838a2b9.txt
# 207:/content/drive/MyDrive/fixed_train/test/5727f10c5188b327a5a6a93e.txt
# 208:/content/drive/MyDrive/fixed_train/test/58279d6ab8c2213722f2ef6b.txt
# 209:/content/drive/MyDrive/fixed_train/test/583b831d065fdb022cca3a0c.txt
# 210:/content/drive/MyDrive/fixed_train/test/5853ed01a28b1d938e25b2d7.txt
# 211:/content/drive/MyDrive/fixed_train/test/58a7b7d31f5e8898403d1607.txt
# 212:/content/drive/MyDrive/fixed_train/test/59cf31f3a5cd8a048a3167d5.txt
# 213:/content/drive/MyDrive/fixed_train/test/5a0cd5dec226a90c3818ec03.txt
# 214:/content/drive/MyDrive/fixed_train/test/5ab7fdd5629656e684c0435a.txt
# 215:/content/drive/MyDrive/fixed_train/test/5b67ae395926dc10ea314317.txt
# 216:/content/drive/MyDrive/fixed_train/test/5b9d1b98227340deb1d6f185.txt
# 217:/content/drive/MyDrive/fixed_train/test/5ca85be3a9fc9cd53ea8c7f1.txt
# 218:/content/drive/MyDrive/fixed_train/test/5df63c6ddcddaa958e520ea5.txt
# 219:/content/drive/MyDrive/fixed_train/test/5e4f084a93b862d00688673d.txt
# 220:/content/drive/MyDrive/fixed_train/test/5e5ee82cd8753120756c78e4.txt
# 221:/content/drive/MyDrive/fixed_train/test/5f0252bc39ee6688384856d4.txt
# 222:/content/drive/MyDrive/fixed_train/test/5f4f516acba921593e55cc4b.txt
# 223:/content/drive/MyDrive/fixed_train/test/5f58ff915fb692e2507cfdd5.txt
# 224:/content/drive/MyDrive/fixed_train/test/60386b96032381bf1c7a33f6.txt
# 225:/content/drive/MyDrive/fixed_train/test/6085d88383432829bafe3147.txt
# 226:/content/drive/MyDrive/fixed_train/test/60bc1c7de6f805c28228b3fe.txt
# 227:/content/drive/MyDrive/fixed_train/test/60d4eac93ce6283cdc6e11b6.txt
# 228:/content/drive/MyDrive/fixed_train/test/60e0899d24db2cbaa927abcd.txt
# 229:/content/drive/MyDrive/fixed_train/test/610f2c07b26508790d1cd355.txt
# 230:/content/drive/MyDrive/fixed_train/test/627d97e6be0e2f1f630bdb37.txt
# 231:/content/drive/MyDrive/fixed_train/test/633b9baf7b8415ee819c26a7.txt
# 232:/content/drive/MyDrive/fixed_train/test/644c8ec6504fe83b80677866.txt
# 233:/content/drive/MyDrive/fixed_train/test/659307d58a1bd977d58bc94f.txt
# 234:/content/drive/MyDrive/fixed_train/test/663ad3a7b78652036aa4290d.txt
# 235:/content/drive/MyDrive/fixed_train/test/66744e8a5c65a748497cd7c0.txt
# 236:/content/drive/MyDrive/fixed_train/test/667e1fd9da2bfe14aafdec4b.txt
# 237:/content/drive/MyDrive/fixed_train/test/66dabc484153c8102481a8e4.txt
# 238:/content/drive/MyDrive/fixed_train/test/672b4e3c9b09a218a4e74974.txt
# 239:/content/drive/MyDrive/fixed_train/test/673bee9ae2df0a2d44d178ec.txt
# 240:/content/drive/MyDrive/fixed_train/test/6751305422c4e62ee256a6f0.txt
# 241:/content/drive/MyDrive/fixed_train/test/679845ce7fb4d5b56d6887c1.txt
# 242:/content/drive/MyDrive/fixed_train/test/67bf4b03fc22542bb6d51daf.txt
# 243:/content/drive/MyDrive/fixed_train/test/6883b003fd96496e062c6ee1.txt
# 244:/content/drive/MyDrive/fixed_train/test/689ac374ec67d0f0b0fe4b0a.txt
# 245:/content/drive/MyDrive/fixed_train/test/6913609ad03d8092c8b5b822.txt
# 246:/content/drive/MyDrive/fixed_train/test/6913691fa6371ba1be81276e.txt
# 247:/content/drive/MyDrive/fixed_train/test/698dc1d1a1885908e8fbfe4c.txt
# 248:/content/drive/MyDrive/fixed_train/test/6ab9bfd01e48a4efe981c6b0.txt
# 249:/content/drive/MyDrive/fixed_train/test/6ae5d7dfba87555bb7bd70e6.txt
# 250:/content/drive/MyDrive/fixed_train/test/6b58ff42c73427fdefe9d2bb.txt
# 251:/content/drive/MyDrive/fixed_train/test/6b598c55272851a4185d23aa.txt
# 252:/content/drive/MyDrive/fixed_train/test/6b61e3eb48c15f554f18de21.txt
# 253:/content/drive/MyDrive/fixed_train/test/6b6d91a5b97ed3c40c1411a7.txt
# 254:/content/drive/MyDrive/fixed_train/test/6c9481054d611cffe044b807.txt
# 255:/content/drive/MyDrive/fixed_train/test/6cef04795d0f3a4313958f16.txt
# 256:/content/drive/MyDrive/fixed_train/test/6d89334316127640cff99800.txt
# 257:/content/drive/MyDrive/fixed_train/test/6dcb3e845f3cab94ca55a790.txt
# 258:/content/drive/MyDrive/fixed_train/test/6e1c6452fd95c2d3e6785f36.txt
# 259:/content/drive/MyDrive/fixed_train/test/6ea1015ef1f27bbd15192eb6.txt
# 260:/content/drive/MyDrive/fixed_train/test/6f705385cf0cebca4b0ca6e7.txt
# 261:/content/drive/MyDrive/fixed_train/test/6fda297cb93a859000e72b70.txt
# 262:/content/drive/MyDrive/fixed_train/test/6fe7c294e3a47e17aeb240b2.txt
# 263:/content/drive/MyDrive/fixed_train/test/70123d9366c5676db1d1d0dd.txt
# 264:/content/drive/MyDrive/fixed_train/test/7015c5709467b8fdb974daf4.txt
# 265:/content/drive/MyDrive/fixed_train/test/7121b385f2dcd034cae8c49d.txt
# 266:/content/drive/MyDrive/fixed_train/test/71675faaf4dedd23ce8e2c39.txt
# 267:/content/drive/MyDrive/fixed_train/test/71d0d1f8c3abeb9d6de37c88.txt
# 268:/content/drive/MyDrive/fixed_train/test/723900eb4d292e35981c3012.txt
# 269:/content/drive/MyDrive/fixed_train/test/7241824cc3075197e0ded020.txt
# 270:/content/drive/MyDrive/fixed_train/test/7264eeec0a8d8aa61e51cd5f.txt
# 271:/content/drive/MyDrive/fixed_train/test/7276fac9b55aa417322e20f8.txt
# 272:/content/drive/MyDrive/fixed_train/test/728aef201c2b68acc370b7f8.txt
# 273:/content/drive/MyDrive/fixed_train/test/72963a8c7eb520c56f88a536.txt
# 274:/content/drive/MyDrive/fixed_train/test/7316acadafc00dbfdb47ca10.txt
# 275:/content/drive/MyDrive/fixed_train/test/73b8ae34d0038aa6dcdcd858.txt
# 276:/content/drive/MyDrive/fixed_train/test/74e1f3f41374ba181468248d.txt
# 277:/content/drive/MyDrive/fixed_train/test/75703a1e62aa93e8c56de7aa.txt
# 278:/content/drive/MyDrive/fixed_train/test/760075793d3822dd8bf1bf31.txt
# 279:/content/drive/MyDrive/fixed_train/test/7603ac27c8a6723a333e9fb8.txt
# 280:/content/drive/MyDrive/fixed_train/test/76f7af4eeffffde457d018bb.txt
# 281:/content/drive/MyDrive/fixed_train/test/76fa8b5e46e6dacbdc4f4f39.txt
# 282:/content/drive/MyDrive/fixed_train/test/7727672abec7d70216173223.txt
# 283:/content/drive/MyDrive/fixed_train/test/77cabd9a8eaaa49beb66a62b.txt
# 284:/content/drive/MyDrive/fixed_train/test/7814e8ec13281ccf89baedc0.txt
# 285:/content/drive/MyDrive/fixed_train/test/7861f68134d801946e3e2795.txt
# 286:/content/drive/MyDrive/fixed_train/test/78790e6e6a7e658c5e25955f.txt
# 287:/content/drive/MyDrive/fixed_train/test/78beda79f100af67d5fd91e6.txt
# 288:/content/drive/MyDrive/fixed_train/test/791c96c9a472e89ec06e8a85.txt
# 289:/content/drive/MyDrive/fixed_train/test/796c8d48da4b59d8c47d2c3a.txt
# 290:/content/drive/MyDrive/fixed_train/test/7987213c53131fd5bbacce4f.txt
# 291:/content/drive/MyDrive/fixed_train/test/79dbd47db3541d41acf3645c.txt
# 292:/content/drive/MyDrive/fixed_train/test/7a4c5c74672a27ba94eb9b66.txt
# 293:/content/drive/MyDrive/fixed_train/test/7a9ed75a485605db82f143d5.txt
# 294:/content/drive/MyDrive/fixed_train/test/7b073c01ca8b6db9a98dd11a.txt
# 295:/content/drive/MyDrive/fixed_train/test/7bc4213a6a76c5cb03de2d69.txt
# 296:/content/drive/MyDrive/fixed_train/test/7be7b7833488818f562d24aa.txt
# 297:/content/drive/MyDrive/fixed_train/test/7c19987b64849e60e831c394.txt
# 298:/content/drive/MyDrive/fixed_train/test/7caee2ed97f52218042a662f.txt
# 299:/content/drive/MyDrive/fixed_train/test/7d2d723a30cce824aad9915b.txt
# 300:/content/drive/MyDrive/fixed_train/test/7d3f0c002431353bc0a54eeb.txt
# 301:/content/drive/MyDrive/fixed_train/test/7d401b038d6fdb08f4f8197d.txt
# 302:/content/drive/MyDrive/fixed_train/test/7d42a67573f38d52bea01679.txt
# 303:/content/drive/MyDrive/fixed_train/test/7e1432b1a371d5d3e8ae34d3.txt
# 304:/content/drive/MyDrive/fixed_train/test/7efc4326b753c9133e0b908e.txt
# 305:/content/drive/MyDrive/fixed_train/test/81532abcb8b4e11eec4a8202.txt
# 306:/content/drive/MyDrive/fixed_train/test/819494b56fdb3e65ef378897.txt
# 307:/content/drive/MyDrive/fixed_train/test/81badbb3aded20c36ae22bc2.txt
# 308:/content/drive/MyDrive/fixed_train/test/82683559aebe665bb0eebe8e.txt
# 309:/content/drive/MyDrive/fixed_train/test/8304231d833d5427ff4f4da1.txt
# 310:/content/drive/MyDrive/fixed_train/test/833d0a5609a088d7c15d2031.txt
# 311:/content/drive/MyDrive/fixed_train/test/83ae65e7f2059dae6c015ab5.txt
# 312:/content/drive/MyDrive/fixed_train/test/852fb29bb4996d022496edcc.txt
# 313:/content/drive/MyDrive/fixed_train/test/8545d8808a11f6b48d112310.txt
# 314:/content/drive/MyDrive/fixed_train/test/854dedd673b748ac7a14c6a7.txt
# 315:/content/drive/MyDrive/fixed_train/test/8584d22e99dc86f336173b15.txt
# 316:/content/drive/MyDrive/fixed_train/test/85a41fe1d8c529c033810499.txt
# 317:/content/drive/MyDrive/fixed_train/test/861c09b1c67351e92708f91f.txt
# 318:/content/drive/MyDrive/fixed_train/test/862a4ac32755d252c6948424.txt
# 319:/content/drive/MyDrive/fixed_train/test/867c78ed47ee3fc4b30b9d59.txt
# 320:/content/drive/MyDrive/fixed_train/test/86a46c7bf9fe29a67980b1a7.txt
# 321:/content/drive/MyDrive/fixed_train/test/876cd27fc8f63a2800fc3de8.txt
# 322:/content/drive/MyDrive/fixed_train/test/8817286b357023b71bd0b696.txt
# 323:/content/drive/MyDrive/fixed_train/test/89500baf14748fe9b3a82748.txt
# 324:/content/drive/MyDrive/fixed_train/test/897457315805f1d5b209c692.txt
# 325:/content/drive/MyDrive/fixed_train/test/89ab0fc4e49d892ff0156dc7.txt
# 326:/content/drive/MyDrive/fixed_train/test/89f1ea2d1e3a876af40dadac.txt
# 327:/content/drive/MyDrive/fixed_train/test/89f92d1370b844b8e7644ee8.txt
# 328:/content/drive/MyDrive/fixed_train/test/8a5e440d8d110c0a3539ee9b.txt
# 329:/content/drive/MyDrive/fixed_train/test/8ab34318f66dffa710ec53cd.txt
# 330:/content/drive/MyDrive/fixed_train/test/8c1a179f5e2fa18a0307a9dd.txt
# 331:/content/drive/MyDrive/fixed_train/test/8c1fdb5fa1bafa5b56ecc4e0.txt
# 332:/content/drive/MyDrive/fixed_train/test/8c4e95647f1f1277f434babc.txt
# 333:/content/drive/MyDrive/fixed_train/test/8c5a946a9eeb739c2a6630ff.txt
# 334:/content/drive/MyDrive/fixed_train/test/8c7c75845cfba8c2b874d2ea.txt
# 335:/content/drive/MyDrive/fixed_train/test/8ca7fe022118929860699a2f.txt
# 336:/content/drive/MyDrive/fixed_train/test/8cb1f56b74af85d3dd0efcd9.txt
# 337:/content/drive/MyDrive/fixed_train/test/8cb8f0045242464f50342338.txt
# 338:/content/drive/MyDrive/fixed_train/test/8ccd3fc53ad2e63651de4376.txt
# 339:/content/drive/MyDrive/fixed_train/test/8d348ecb29022e18299be281.txt
# 340:/content/drive/MyDrive/fixed_train/test/8d64c2a46bc9b91426969ef6.txt
# 341:/content/drive/MyDrive/fixed_train/test/8e577bbf235d81ce625e363a.txt
# 342:/content/drive/MyDrive/fixed_train/test/8edbfe4ea14f5b8fe8f47f15.txt
# 343:/content/drive/MyDrive/fixed_train/test/8f134b651d254092c94e855f.txt
# 344:/content/drive/MyDrive/fixed_train/test/8febc00382b315a208c3d9eb.txt
# 345:/content/drive/MyDrive/fixed_train/test/8ffb53cd60edc17b04e25a45.txt
# 346:/content/drive/MyDrive/fixed_train/test/90119ff42ce5621a5761dfdf.txt
# 347:/content/drive/MyDrive/fixed_train/test/90e36817a15d1303999b17c9.txt
# 348:/content/drive/MyDrive/fixed_train/test/9113be4094a68ba42ad9daa8.txt
# 349:/content/drive/MyDrive/fixed_train/test/9217871066df2966c942b2eb.txt
# 350:/content/drive/MyDrive/fixed_train/test/9342f71811c45c856bf964c7.txt
# 351:/content/drive/MyDrive/fixed_train/test/9432b20a613c4c0a40993531.txt
# 352:/content/drive/MyDrive/fixed_train/test/947e17f82dbddfbdb4cb2447.txt
# 353:/content/drive/MyDrive/fixed_train/test/949b5f7dd5469b2b7c4d57b4.txt
# 354:/content/drive/MyDrive/fixed_train/test/950c991710b1054f4cd03133.txt
# 355:/content/drive/MyDrive/fixed_train/test/9609fb2f1c62cf3b7ac08521.txt
# 356:/content/drive/MyDrive/fixed_train/test/965778109ccdb3eb34af8bf0.txt
# 357:/content/drive/MyDrive/fixed_train/test/967b41cea41974071e36f31d.txt
# 358:/content/drive/MyDrive/fixed_train/test/9690a79f77581d8c60302d2c.txt
# 359:/content/drive/MyDrive/fixed_train/test/97aad1488e3b02f180a8ae09.txt
# 360:/content/drive/MyDrive/fixed_train/test/97c46c1fc7ebc5930af75743.txt
# 361:/content/drive/MyDrive/fixed_train/test/986924433ab01afa81a59e7a.txt
# 362:/content/drive/MyDrive/fixed_train/test/987dedd74979b11fe4f06987.txt
# 363:/content/drive/MyDrive/fixed_train/test/98942ecbc18dc774835563aa.txt
# 364:/content/drive/MyDrive/fixed_train/test/9950fd1962191dfe62c8a366.txt
# 365:/content/drive/MyDrive/fixed_train/test/99ea88fcd02f1d7cb4d141bf.txt
# 366:/content/drive/MyDrive/fixed_train/test/9a9cf9f796fae7f3f8643a04.txt
# 367:/content/drive/MyDrive/fixed_train/test/9b720b32ec8fac3b82f19ae1.txt
# 368:/content/drive/MyDrive/fixed_train/test/9b97a70dcbae27c225bd36f9.txt
# 369:/content/drive/MyDrive/fixed_train/test/9bed5343c25574e44914ef21.txt
# 370:/content/drive/MyDrive/fixed_train/test/9cc4412ff73ec37e30be9d9f.txt
# 371:/content/drive/MyDrive/fixed_train/test/9d5db7dab58374e88b12d227.txt
# 372:/content/drive/MyDrive/fixed_train/test/9d89ba9627651adaa7fbf78f.txt
# 373:/content/drive/MyDrive/fixed_train/test/9dd916c57ffba275b1baa323.txt
# 374:/content/drive/MyDrive/fixed_train/test/9dedc3819b9ac8444b1f30f4.txt
# 375:/content/drive/MyDrive/fixed_train/test/9e001583893cabee64bf69df.txt
# 376:/content/drive/MyDrive/fixed_train/test/9e014c6bd4f50e1256624ae5.txt
# 377:/content/drive/MyDrive/fixed_train/test/9eab95aa6e3838f3fbccf311.txt
# 378:/content/drive/MyDrive/fixed_train/test/9fd3fbeb694c4b7a37c125d5.txt
# 379:/content/drive/MyDrive/fixed_train/test/a0c05d232b01247a9ba48be0.txt
# 380:/content/drive/MyDrive/fixed_train/test/a11615477afe31e7a204287f.txt
# 381:/content/drive/MyDrive/fixed_train/test/a1a32c28854aeef857ef79a5.txt
# 382:/content/drive/MyDrive/fixed_train/test/a1a53ec2c1992d3947dd4480.txt
# 383:/content/drive/MyDrive/fixed_train/test/a221eeef88b64a9e58c95f6f.txt
# 384:/content/drive/MyDrive/fixed_train/test/a23ca542020c3376f8da1fd9.txt
# 385:/content/drive/MyDrive/fixed_train/test/a25a8d841f9dcb508c5ee363.txt
# 386:/content/drive/MyDrive/fixed_train/test/a25f020b7571d262ff5952ed.txt
# 387:/content/drive/MyDrive/fixed_train/test/a2627e7d41e7e1c686bb74f9.txt
# 388:/content/drive/MyDrive/fixed_train/test/a2b5878c25761e552230d412.txt
# 389:/content/drive/MyDrive/fixed_train/test/a3c5aadf824a220327e9cdc6.txt
# 390:/content/drive/MyDrive/fixed_train/test/a403d556f6ebc1343e0b27ee.txt
# 391:/content/drive/MyDrive/fixed_train/test/a424b6ad3de377df7c9e8958.txt
# 392:/content/drive/MyDrive/fixed_train/test/a4609e6c40ba7c527c8c5da2.txt
# 393:/content/drive/MyDrive/fixed_train/test/a4ab6c6c78b232568f975f16.txt
# 394:/content/drive/MyDrive/fixed_train/test/a526dbdf164aa0a28f510c49.txt
# 395:/content/drive/MyDrive/fixed_train/test/a55eb4ea2b0556f96143f176.txt
# 396:/content/drive/MyDrive/fixed_train/test/a57f8728343b9cb2491e6c86.txt
# 397:/content/drive/MyDrive/fixed_train/test/a5b8249fca6d41f4ce1d4a02.txt
# 398:/content/drive/MyDrive/fixed_train/test/a5e437e7708788a70e8bc8ec.txt
# 399:/content/drive/MyDrive/fixed_train/test/a606cb39b74b8e0d45c8c8b8.txt
# 400:/content/drive/MyDrive/fixed_train/test/a7b032ef5441a07e68f073be.txt
# 401:/content/drive/MyDrive/fixed_train/test/a7bb61478b112c3eedcbb6ed.txt
# 402:/content/drive/MyDrive/fixed_train/test/a7e5d323e7ba3df29a4bb918.txt
# 403:/content/drive/MyDrive/fixed_train/test/a850f1538a738b74d58cb9bf.txt
# 404:/content/drive/MyDrive/fixed_train/test/a87fa5784fd6e0791efe650a.txt
# 405:/content/drive/MyDrive/fixed_train/test/a8cf094dbb3c22d02d10e21d.txt
# 406:/content/drive/MyDrive/fixed_train/test/a9cc261267276e486328a30d.txt
# 407:/content/drive/MyDrive/fixed_train/test/aa3bb82db66286095d941035.txt
# 408:/content/drive/MyDrive/fixed_train/test/aa49b4006c18d1d2a28cd049.txt
# 409:/content/drive/MyDrive/fixed_train/test/aa8383281d2c90c5576bb4e7.txt
# 410:/content/drive/MyDrive/fixed_train/test/ac1a2e8f11ab64d729199969.txt
# 411:/content/drive/MyDrive/fixed_train/test/ac83e97550ad3e7396fb618b.txt
# 412:/content/drive/MyDrive/fixed_train/test/ac93c263f13fb5eda552ca97.txt
# 413:/content/drive/MyDrive/fixed_train/test/ad228ceb56e37f3416a910a3.txt
# 414:/content/drive/MyDrive/fixed_train/test/ad40d2b657a1b847b11b013f.txt
# 415:/content/drive/MyDrive/fixed_train/test/ad733a1791d3fdd21532677b.txt
# 416:/content/drive/MyDrive/fixed_train/test/ad97a5e58725339a560c381e.txt
# 417:/content/drive/MyDrive/fixed_train/test/adb909f464fd9284b53dbc87.txt
# 418:/content/drive/MyDrive/fixed_train/test/adda251cb945aa23e455ab48.txt
# 419:/content/drive/MyDrive/fixed_train/test/ae2dc138bd8552bf6c785377.txt
# 420:/content/drive/MyDrive/fixed_train/test/ae4af47ef601ee8664a18778.txt
# 421:/content/drive/MyDrive/fixed_train/test/aec3b618b191da96f0eb2c10.txt
# 422:/content/drive/MyDrive/fixed_train/test/aed8d49bbf0857e88e1d26b5.txt
# 423:/content/drive/MyDrive/fixed_train/test/afd41e65cb00646768654b9c.txt
# 424:/content/drive/MyDrive/fixed_train/test/b03a2291b48aa904314717db.txt
# 425:/content/drive/MyDrive/fixed_train/test/b1181f6f7f7f4bb4ec48e5c4.txt
# 426:/content/drive/MyDrive/fixed_train/test/b1b61e500f46136f8ee8e94f.txt
# 427:/content/drive/MyDrive/fixed_train/test/b1f1e78acfb77ad82d538183.txt
# 428:/content/drive/MyDrive/fixed_train/test/b2c1f3b0b84bae349a85a76f.txt
# 429:/content/drive/MyDrive/fixed_train/test/b2dd56b88cf0d00902503eba.txt
# 430:/content/drive/MyDrive/fixed_train/test/b308a8c4ffeee07f455ffb19.txt
# 431:/content/drive/MyDrive/fixed_train/test/b36d5f0beec291379d2181b6.txt
# 432:/content/drive/MyDrive/fixed_train/test/b37fa5dff7ba5b417031990d.txt
# 433:/content/drive/MyDrive/fixed_train/test/b3ddea2aa88e2015223b75a8.txt
# 434:/content/drive/MyDrive/fixed_train/test/b406c5c925f3b64d8972b2c0.txt
# 435:/content/drive/MyDrive/fixed_train/test/b40da1395a4ea396026ea3fa.txt
# 436:/content/drive/MyDrive/fixed_train/test/b4188fc441162ab5593a7b45.txt
# 437:/content/drive/MyDrive/fixed_train/test/b433961afd6c429fc2dd0971.txt
# 438:/content/drive/MyDrive/fixed_train/test/b47cbb269b2ddf36e39572bd.txt
# 439:/content/drive/MyDrive/fixed_train/test/b51a662297b90657f0b03b44.txt
# 440:/content/drive/MyDrive/fixed_train/test/b59c09efbc2ba31f7df1d0d1.txt
# 441:/content/drive/MyDrive/fixed_train/test/b6f2d87525cec0dcd65b693c.txt
# 442:/content/drive/MyDrive/fixed_train/test/b760d372b55d88f398110f48.txt
# 443:/content/drive/MyDrive/fixed_train/test/b781698c482098426072d432.txt
# 444:/content/drive/MyDrive/fixed_train/test/b7987955dad0b6685500132b.txt
# 445:/content/drive/MyDrive/fixed_train/test/b7deb644d3ec40fb81cad6e2.txt
# 446:/content/drive/MyDrive/fixed_train/test/b82e65dde03a9ff7b676fd37.txt
# 447:/content/drive/MyDrive/fixed_train/test/b87667c3dd21d8aa17bb6a74.txt
# 448:/content/drive/MyDrive/fixed_train/test/b8b2f59af006df03c9d3e0d6.txt
# 449:/content/drive/MyDrive/fixed_train/test/b8d7ddb54d74a9450d7eb17c.txt
# 450:/content/drive/MyDrive/fixed_train/test/bb73ec8779aaa0509bea454a.txt
# 451:/content/drive/MyDrive/fixed_train/test/bb84ab5e77fc9f5fdbd52827.txt
# 452:/content/drive/MyDrive/fixed_train/test/bb8d876705a0d8b453791035.txt
# 453:/content/drive/MyDrive/fixed_train/test/bb938cd9fec6ef383e40f4c0.txt
# 454:/content/drive/MyDrive/fixed_train/test/bbcf74a04032515b461cb2cc.txt
# 455:/content/drive/MyDrive/fixed_train/test/bbe172d896a38bc15fca3062.txt
# 456:/content/drive/MyDrive/fixed_train/test/bc253f69b5d49855785d94da.txt
# 457:/content/drive/MyDrive/fixed_train/test/bd0f2c8626679895f3338ca5.txt
# 458:/content/drive/MyDrive/fixed_train/test/bd27a637d58beacf9a51c292.txt
# 459:/content/drive/MyDrive/fixed_train/test/bd5921cd1008382e2f537b53.txt
# 460:/content/drive/MyDrive/fixed_train/test/bd6637f1fa9e0074495caaca.txt
# 461:/content/drive/MyDrive/fixed_train/test/bf132134be51ec4891e9e16c.txt
# 462:/content/drive/MyDrive/fixed_train/test/bf4fb3d50ba5202800859799.txt
# 463:/content/drive/MyDrive/fixed_train/test/bf5543efb9497b2dd44ca7da.txt
# 464:/content/drive/MyDrive/fixed_train/test/bfcb651b80df271b79d344dd.txt
# 465:/content/drive/MyDrive/fixed_train/test/c06224bdefec4d102f001601.txt
# 466:/content/drive/MyDrive/fixed_train/test/c0f79f21ad5f32c573f98886.txt
# 467:/content/drive/MyDrive/fixed_train/test/c1bee305c2d4212c18c91e4e.txt
# 468:/content/drive/MyDrive/fixed_train/test/c26b88f19f04117b7e4dd747.txt
# 469:/content/drive/MyDrive/fixed_train/test/c2ae6f835a79f6fd53600449.txt
# 470:/content/drive/MyDrive/fixed_train/test/c32f4436326c9589169be1dd.txt
# 471:/content/drive/MyDrive/fixed_train/test/c385db2d2886056b8c42a9e6.txt
# 472:/content/drive/MyDrive/fixed_train/test/c3913710fd39499173a055e7.txt
# 473:/content/drive/MyDrive/fixed_train/test/c49c72f7f7036cc8a661917e.txt
# 474:/content/drive/MyDrive/fixed_train/test/c50cc8ab7c5008f50a38e70d.txt
# 475:/content/drive/MyDrive/fixed_train/test/c5c86b509c716c7872e16214.txt
# 476:/content/drive/MyDrive/fixed_train/test/c61792dc8a5208a73bfea103.txt
# 477:/content/drive/MyDrive/fixed_train/test/c694a61c01738864eacd4d5e.txt
# 478:/content/drive/MyDrive/fixed_train/test/c70272750cc48acef9827dcb.txt
# 479:/content/drive/MyDrive/fixed_train/test/c7ace6aca412926c8c25155e.txt
# 480:/content/drive/MyDrive/fixed_train/test/c7c9d2f5113d91afa2b7e94d.txt
# 481:/content/drive/MyDrive/fixed_train/test/c7eaa26e0dcb8d3680fd3c70.txt
# 482:/content/drive/MyDrive/fixed_train/test/c816924dba6739d9c63021f7.txt
# 483:/content/drive/MyDrive/fixed_train/test/c83dfe151e943e78333cec13.txt
# 484:/content/drive/MyDrive/fixed_train/test/c93b48c40c3f32e200619f99.txt
# 485:/content/drive/MyDrive/fixed_train/test/c9a69eab2313afa2086a7927.txt
# 486:/content/drive/MyDrive/fixed_train/test/c9f3dcee23725759730eaf32.txt
# 487:/content/drive/MyDrive/fixed_train/test/ca363c1b30692cf0598bea76.txt
# 488:/content/drive/MyDrive/fixed_train/test/cad1ea3fa0502ba1bcbebd6d.txt
# 489:/content/drive/MyDrive/fixed_train/test/cad7c5c53d62719991fc4c07.txt
# 490:/content/drive/MyDrive/fixed_train/test/cb278289e8158f129e31cfcd.txt
# 491:/content/drive/MyDrive/fixed_train/test/cb9399bab0ead661258086ae.txt
# 492:/content/drive/MyDrive/fixed_train/test/cbe53b25f9fd9c9acea1e6d1.txt
# 493:/content/drive/MyDrive/fixed_train/test/cc23760c1abbefee0791b1f2.txt
# 494:/content/drive/MyDrive/fixed_train/test/cc8cd263619bc078e1d10ebf.txt
# 495:/content/drive/MyDrive/fixed_train/test/cd695bf43420d73e23df3d5a.txt
# 496:/content/drive/MyDrive/fixed_train/test/cd7cbeadf3cd476110f10c14.txt
# 497:/content/drive/MyDrive/fixed_train/test/ce09e807fef6de6b45709d9f.txt
# 498:/content/drive/MyDrive/fixed_train/test/ce80c08d743f15e6586741f6.txt
# 499:/content/drive/MyDrive/fixed_train/test/cebe97fd2e7949b281656193.txt
# 500:/content/drive/MyDrive/fixed_train/test/cf1da59d0470e29891469f3c.txt
# 501:/content/drive/MyDrive/fixed_train/test/cf505e00f50df4548ef98d05.txt
# 502:/content/drive/MyDrive/fixed_train/test/cf5c7ff181051df6e88a5787.txt
# 503:/content/drive/MyDrive/fixed_train/test/cf5cc112ba8a1bbb6f8d93e8.txt
# 504:/content/drive/MyDrive/fixed_train/test/cfda785b67b4b17c58b911b0.txt
# 505:/content/drive/MyDrive/fixed_train/test/d0ba1a514581ead3c796490b.txt
# 506:/content/drive/MyDrive/fixed_train/test/d0be93dbc89e6791ec20afc9.txt
# 507:/content/drive/MyDrive/fixed_train/test/d148573a2b01245f06e1de50.txt
# 508:/content/drive/MyDrive/fixed_train/test/d2a8a8bd9569c33bc43ec14e.txt
# 509:/content/drive/MyDrive/fixed_train/test/d3402272ac97751e0e87cdf3.txt
# 510:/content/drive/MyDrive/fixed_train/test/d3db994677fd0e0ed62339d2.txt
# 511:/content/drive/MyDrive/fixed_train/test/d592885af4e6e380c376dc55.txt
# 512:/content/drive/MyDrive/fixed_train/test/d66110d1c177307120b5deb2.txt
# 513:/content/drive/MyDrive/fixed_train/test/d670943e9fa2473914f568d4.txt
# 514:/content/drive/MyDrive/fixed_train/test/d6820b1b6728bdb201ab7805.txt
# 515:/content/drive/MyDrive/fixed_train/test/d6daf4cca1df91ce7f5ca2c6.txt
# 516:/content/drive/MyDrive/fixed_train/test/d6e09245089299ec8e5173e7.txt
# 517:/content/drive/MyDrive/fixed_train/test/d712536c776ed08ddfcb73c6.txt
# 518:/content/drive/MyDrive/fixed_train/test/d72ceac4628436a540910d98.txt
# 519:/content/drive/MyDrive/fixed_train/test/d7c936e862946ca5f6926512.txt
# 520:/content/drive/MyDrive/fixed_train/test/d817eb4bd2f39280ea1037b9.txt
# 521:/content/drive/MyDrive/fixed_train/test/d905d9e3a421b0ad31a8a7c0.txt
# 522:/content/drive/MyDrive/fixed_train/test/d95450e3be51a1d7d284a29b.txt
# 523:/content/drive/MyDrive/fixed_train/test/da7678bc04757fa05f1f7992.txt
# 524:/content/drive/MyDrive/fixed_train/test/db152e591fe88b82b706da8d.txt
# 525:/content/drive/MyDrive/fixed_train/test/db7b0850aed5577702f151c4.txt
# 526:/content/drive/MyDrive/fixed_train/test/dbc3537c9913889864ebe0c1.txt
# 527:/content/drive/MyDrive/fixed_train/test/dbc35fa5280de4c5d553d23a.txt
# 528:/content/drive/MyDrive/fixed_train/test/dbc4e9263d1a2efd4b7b89fc.txt
# 529:/content/drive/MyDrive/fixed_train/test/dc5f905014579b7fb857d2f0.txt
# 530:/content/drive/MyDrive/fixed_train/test/dc616633d076e209c093f8ac.txt
# 531:/content/drive/MyDrive/fixed_train/test/dc641944142a65f5ddf845bb.txt
# 532:/content/drive/MyDrive/fixed_train/test/dc78498813d06eff01a96320.txt
# 533:/content/drive/MyDrive/fixed_train/test/dc7aab767a608ca73ea2e33b.txt
# 534:/content/drive/MyDrive/fixed_train/test/dcd4bfc49601637d9339808d.txt
# 535:/content/drive/MyDrive/fixed_train/test/dce5ec866b612e86ec04ac06.txt
# 536:/content/drive/MyDrive/fixed_train/test/dd4cbd69218f610f27cf33c8.txt
# 537:/content/drive/MyDrive/fixed_train/test/dde666fd35199cb019c8ea62.txt
# 538:/content/drive/MyDrive/fixed_train/test/de9160a4b1db66a453ebfb68.txt
# 539:/content/drive/MyDrive/fixed_train/test/de9cef0d69383e47bd74a64c.txt
# 540:/content/drive/MyDrive/fixed_train/test/decc9a540ad050e541a897c3.txt
# 541:/content/drive/MyDrive/fixed_train/test/df4798f4f3b3c5c510e237ad.txt
# 542:/content/drive/MyDrive/fixed_train/test/dffd0a427bc76233ef658a1d.txt
# 543:/content/drive/MyDrive/fixed_train/test/e05290eced3105a1b99ee13a.txt
# 544:/content/drive/MyDrive/fixed_train/test/e1539744b6f7668a040ac968.txt
# 545:/content/drive/MyDrive/fixed_train/test/e1c113233943f6191b64441c.txt
# 546:/content/drive/MyDrive/fixed_train/test/e2183337d2df7034a6c80cf3.txt
# 547:/content/drive/MyDrive/fixed_train/test/e3455e53350336857caf08f0.txt
# 548:/content/drive/MyDrive/fixed_train/test/e39b941dd2bcc2bffdc433b1.txt
# 549:/content/drive/MyDrive/fixed_train/test/e3d5b272b2c71179e501519e.txt
# 550:/content/drive/MyDrive/fixed_train/test/e492f8f51c101a523a137755.txt
# 551:/content/drive/MyDrive/fixed_train/test/e52fbc1a0b00f58b565066c9.txt
# 552:/content/drive/MyDrive/fixed_train/test/e5c6641300c3ace88914ec7f.txt
# 553:/content/drive/MyDrive/fixed_train/test/e6fcb043744edde3b9f0559b.txt
# 554:/content/drive/MyDrive/fixed_train/test/e70ce41f2b7ce9cdb7045972.txt
# 555:/content/drive/MyDrive/fixed_train/test/e7574977ef4bd5f7a8bd9751.txt
# 556:/content/drive/MyDrive/fixed_train/test/e83a1c294b5d138339149fcb.txt
# 557:/content/drive/MyDrive/fixed_train/test/e83cee96a0e4c29297699594.txt
# 558:/content/drive/MyDrive/fixed_train/test/e8ba16dafb39e5cd1b38f813.txt
# 559:/content/drive/MyDrive/fixed_train/test/e8bf0626e27589d807a9751d.txt
# 560:/content/drive/MyDrive/fixed_train/test/e8c5c09da1a03d6a980ebf8c.txt
# 561:/content/drive/MyDrive/fixed_train/test/e8ed3f22ef83d9515ce36e8f.txt
# 562:/content/drive/MyDrive/fixed_train/test/e91afaba9603500e8e28a454.txt
# 563:/content/drive/MyDrive/fixed_train/test/e9816721ed502a5414ee6aa4.txt
# 564:/content/drive/MyDrive/fixed_train/test/e9db664dfc3a965581a24972.txt
# 565:/content/drive/MyDrive/fixed_train/test/ea0f8a9d4c8009cb6ee8f738.txt
# 566:/content/drive/MyDrive/fixed_train/test/ea18b971347e2ce438bf4557.txt
# 567:/content/drive/MyDrive/fixed_train/test/ea6f61a237dc4e79b251422a.txt
# 568:/content/drive/MyDrive/fixed_train/test/ea777463a91a1293fc79fc52.txt
# 569:/content/drive/MyDrive/fixed_train/test/eafbdd565c2e1e7650607e43.txt
# 570:/content/drive/MyDrive/fixed_train/test/eb1988b0b15be78203297cbf.txt
# 571:/content/drive/MyDrive/fixed_train/test/eb40b68130e8aa8d7dc82c23.txt
# 572:/content/drive/MyDrive/fixed_train/test/eb4de03a42f451c11ffec60c.txt
# 573:/content/drive/MyDrive/fixed_train/test/eb50a89699cb96502bcbb033.txt
# 574:/content/drive/MyDrive/fixed_train/test/ec9aee8ee72b1902bd83edf5.txt
# 575:/content/drive/MyDrive/fixed_train/test/ec9f3bbadfdd3464ed3ddf28.txt
# 576:/content/drive/MyDrive/fixed_train/test/eca017e97a25f3e4832fdb91.txt
# 577:/content/drive/MyDrive/fixed_train/test/ed240a8a5738be91c3743e7f.txt
# 578:/content/drive/MyDrive/fixed_train/test/ed2caa67ce313a4baf428ace.txt
# 579:/content/drive/MyDrive/fixed_train/test/ed77f28aeaf89b317bc380fa.txt
# 580:/content/drive/MyDrive/fixed_train/test/ed7d88f09de7395a7de74ce4.txt
# 581:/content/drive/MyDrive/fixed_train/test/ee1f4765f6d48f2d405b52ba.txt
# 582:/content/drive/MyDrive/fixed_train/test/ee40c6e25fe024d5da451909.txt
# 583:/content/drive/MyDrive/fixed_train/test/ee89473de9b2774fd7d8f029.txt
# 584:/content/drive/MyDrive/fixed_train/test/ee9be1ad62ff5b8c6a44dc3a.txt
# 585:/content/drive/MyDrive/fixed_train/test/eeb5b1d0e23c0675e095b98a.txt
# 586:/content/drive/MyDrive/fixed_train/test/eef7be7d57a15ecb1ab3c578.txt
# 587:/content/drive/MyDrive/fixed_train/test/ef20280811313a39e58e3a08.txt
# 588:/content/drive/MyDrive/fixed_train/test/ef848c8ded4aed6c886ceaf8.txt
# 589:/content/drive/MyDrive/fixed_train/test/efb57307a13583ba06bd099c.txt
# 590:/content/drive/MyDrive/fixed_train/test/f043e6ddf42667290fa8b239.txt
# 591:/content/drive/MyDrive/fixed_train/test/f0d402a465655bfc8ab41242.txt
# 592:/content/drive/MyDrive/fixed_train/test/f1571d150cf1aafde30fd79a.txt
# 593:/content/drive/MyDrive/fixed_train/test/f1d0b39dc36699ffe5d68e4d.txt
# 594:/content/drive/MyDrive/fixed_train/test/f31f1f8ec42e10d23cb54ec4.txt
# 595:/content/drive/MyDrive/fixed_train/test/f4bd7479dbe91f3d18f44c49.txt
# 596:/content/drive/MyDrive/fixed_train/test/f5868ddf1e5f4ccf9a648517.txt
# 597:/content/drive/MyDrive/fixed_train/test/f5fa36c503893adeb5294d52.txt
# 598:/content/drive/MyDrive/fixed_train/test/f6228876966d7dae2c39b8ca.txt
# 599:/content/drive/MyDrive/fixed_train/test/f64fb235136206764a4c23fc.txt
# 600:/content/drive/MyDrive/fixed_train/test/f6eb59b252c21c171d2ce58c.txt
# 601:/content/drive/MyDrive/fixed_train/test/f75c0093a23e5653b6f6b26c.txt
# 602:/content/drive/MyDrive/fixed_train/test/f7ac4e6a8689647696b64804.txt
# 603:/content/drive/MyDrive/fixed_train/test/f7c16e803908d3ab6ee0c603.txt
# 604:/content/drive/MyDrive/fixed_train/test/f7e3f9a90a270fed8f32b3b7.txt
# 605:/content/drive/MyDrive/fixed_train/test/f8a2489aa99b08ffddc115ec.txt
# 606:/content/drive/MyDrive/fixed_train/test/f8ca6722d390d090d4974316.txt
# 607:/content/drive/MyDrive/fixed_train/test/f8d84977825b44af9aa220c4.txt
# 608:/content/drive/MyDrive/fixed_train/test/f8ebbce91c3aa8870faba81e.txt
# 609:/content/drive/MyDrive/fixed_train/test/f95509fd9560e94d6b4d9b2d.txt
# 610:/content/drive/MyDrive/fixed_train/test/f971e55da42b78e4d7a628e8.txt
# 611:/content/drive/MyDrive/fixed_train/test/f973ee415265be4addc457b1.txt
# 612:/content/drive/MyDrive/fixed_train/test/f9f99869dad1b2021ec7a7e2.txt
# 613:/content/drive/MyDrive/fixed_train/test/fa4d3f7e66fdb499255ddaf8.txt
# 614:/content/drive/MyDrive/fixed_train/test/fbd3c96ffd27e8384d298406.txt
# 615:/content/drive/MyDrive/fixed_train/test/fbfbf091d226818a4fc3516c.txt
# 616:/content/drive/MyDrive/fixed_train/test/fc01ec821b1c8cf910b4b895.txt
# 617:/content/drive/MyDrive/fixed_train/test/fc3a6efa90c6712df8739fc1.txt
# 618:/content/drive/MyDrive/fixed_train/test/fc99dca042a1ed67dc80a0fe.txt
# 619:/content/drive/MyDrive/fixed_train/test/fca68c2a470d254cece58870.txt
# 620:/content/drive/MyDrive/fixed_train/test/fd4eee038c0ad7f0179e337e.txt
# 621:/content/drive/MyDrive/fixed_train/test/fd64de8c4a2fc5ebb0e9f412.txt
# 622:/content/drive/MyDrive/fixed_train/test/fd76cacb0312c4bd96701f09.txt
# 623:/content/drive/MyDrive/fixed_train/test/fdac8be560a05943aba7e41f.txt
# 624:/content/drive/MyDrive/fixed_train/test/ff141af01177f34e9caa7a12.txt
# 625:/content/drive/MyDrive/fixed_train/test/ffcd9524c80c0fa5bb859eaf.txt

# %%
shutil.move('test.csv', '/content/drive/MyDrive/nn_wifi_50_beacon_10_10')
# Out:
# '/content/drive/MyDrive/nn_wifi_50_beacon_10_10/test.csv'

# %%
test_all = pd.read_csv('/content/drive/MyDrive/nn_wifi_50_beacon_10_10/test.csv')
test_all.to_pickle('test_all.pkl')
shutil.move('test_all.pkl', '/content/drive/MyDrive/nn_wifi_50_beacon_10_10')
# Out:
# '/content/drive/MyDrive/nn_wifi_50_beacon_10_10/test_all.pkl'
