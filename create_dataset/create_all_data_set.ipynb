# %% [markdown]
# <a href="https://colab.research.google.com/github/kyochanpy/Kaggle_Indoor_Location_Navigation/blob/main/create_dataset/create_all_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import glob
import os
import gc
import json 
import shutil
from sklearn.preprocessing import LabelEncoder

# %%
# pull out all the buildings actually used in the test set, given current method we don't need the other ones
ssubm = pd.read_csv('/content/drive/MyDrive/sample_submission.csv')

# only 24 of the total buildings are used in the test set, 
# this allows us to greatly reduce the intial size of the dataset

ssubm_df = ssubm["site_path_timestamp"].apply(lambda x: pd.Series(x.split("_")))
used_buildings = sorted(ssubm_df[0].value_counts().index.tolist())

# dictionary used to map the floor codes to the values used in the submission file. 
floor_map = {"B2":-2, "B1":-1, "F1":0, "F2": 1, "F3":2, "F4":3, "F5":4, "F6":5, "F7":6,"F8":7, "F9":8,
             "1F":0, "2F":1, "3F":2, "4F":3, "5F":4, "6F":5, "7F":6, "8F": 7, "9F":8}

# %%
train_ = pd.read_csv('/content/drive/MyDrive/all_data_24/train/5a0546857ecc773753327266_train.csv')
test_ = pd.read_csv('/content/drive/MyDrive/all_data_24/test/5a0546857ecc773753327266_test.csv')

train_.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3405,3406,3407,3411) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 0.1  ...  rotation_vector_y  rotation_vector_z
# 0           0             4  ...                NaN                NaN
# 1           1             4  ...                NaN                NaN
# 2           2             4  ...           0.134764           0.984518
# 3           3             4  ...           0.134764           0.984518
# 4           4             4  ...           0.134764           0.984518
#
# [5 rows x 3450 columns]

# %%
a = train_.loc[:, ['x', 'y', 'timestamp']]

# %%
test_['path']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'path'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f43168ac42cc> in <module>()
# ----> 1 test_['path']
#
# ...

# %%
for building in used_buildings:
    df = pd.read_csv(f'/content/drive/MyDrive/all_data_24/train/{building}_train.csv')
    df_a = df.loc[:, ['x', 'y', 'timestamp']]
    df = df.drop(['x', 'y', 'timestamp'], axis=1)
    df['x'], df['y'], df['timestamp'] = df_a.values
    df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
    df.to_csv(f'{building}_train.csv')
    shutil.move(f'{building}_train.csv', '/content/drive/MyDrive/all_data')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3405,3406,3407,3411) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-8ecbdabb36eb> in <module>()
#       3     df_a = df.loc[:, ['x', 'y', 'timestamp']]
#       4     df = df.drop(['x', 'y', 'timestamp'], axis=1)
# ----> 5     df['x'], df['y'], df['timestamp'] = df_a.values
#       6     df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
#       7     df.to_csv(f'{building}_train.csv')
#
# ValueError: too many values to unpack (expected 3)

# %%
for building in used_buildings:
    df = pd.read_csv(f'/content/drive/MyDrive/all_data_24/test/{building}_test.csv')
    df_a = df.loc[:,'timestamp']
    df = df.drop('timestamp', axis=1)
    df['timestamp'] = df_a
    df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
    df.to_csv(f'{building}_test.csv')
    shutil.move(f'{building}_test.csv', '/content/drive/MyDrive/all_data')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1918,1919,1920,1924) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1314,1315,1316,1320) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3504,3505,3506,3510) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4524,4525,4526,4530) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
c = pd.read_csv('/content/drive/MyDrive/all_data/5a0546857ecc773753327266_train.csv')
c['timestamp']
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3403,3404,3405,3409) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0       timestamp
# 1       timestamp
# 2       timestamp
# 3       timestamp
# 4       timestamp
#           ...
# 9291    timestamp
# 9292    timestamp
# 9293    timestamp
# 9294    timestamp
# 9295    timestamp
# Name: timestamp, Length: 9296, dtype: object
