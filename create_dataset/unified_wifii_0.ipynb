# %% [markdown]
# <a href="https://colab.research.google.com/github/kyochanpy/Kaggle_Indoor_Location_Navigation/blob/main/create_dataset/unified_wifii_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import glob
import os

import multiprocessing
from multiprocessing import Pool

num_cores = multiprocessing.cpu_count()

# %%
ITEMS_TO_TAKE = 100

# %%
feature_dir = "/content/drive/MyDrive/wifi_0"
train_files = sorted(glob.glob(os.path.join(feature_dir, '*_train.csv')))
test_files = sorted(glob.glob(os.path.join(feature_dir, '*_test.csv')))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def generate_training_data(train_file):
    train = pd.read_csv(train_file)

    file_name = train_file.split('/')[-1]

    num_of_lines = train.shape[0]
    print(f'{file_name} : {num_of_lines}')

    data = []
    for i in range(num_of_lines):
        if i % 100 == 0:
            print(f'current:{i}')

        tmp = train.iloc[i,1:-4].astype(int).sort_values(ascending=False).head(ITEMS_TO_TAKE)
        target = train.iloc[i,-4:]
        line = [*tmp.index.astype(str), *tmp.values, *target]
        data.append(line)
    data = pd.DataFrame(data)
    data.columns = [f'bssid_{str(i)}' for i in range(ITEMS_TO_TAKE)] + [f'rssi_{str(i)}' for i in range(ITEMS_TO_TAKE)] + ['x','y','floor','path']
    data.to_csv(f'Unified_WiFi_{file_name}', index=False)

# %%
with Pool(num_cores) as pool:
    pool.map(generate_training_data, [t for t in train_files])
# Out:
# 5a0546857ecc773753327266_0_train.csv : 9296
# current:0
# current:100
# current:200
# current:300
# current:400
# 5d27096c03f801723c31e5e0_0_train.csv : 9100
# current:0
# current:500
# current:600
# current:100
# current:700
# current:200
# current:800
# current:300
# current:900
# current:1000
# current:400
# current:1100
# current:500
# current:1200
# current:1300
# current:600
# current:1400
# current:700
# current:1500
# current:800
# current:1600
# current:1700
# current:900
# current:1800
# current:1000
# current:1900
# current:1100
# current:2000
# current:2100
# current:1200
# current:2200
# current:1300
# current:2300
# current:2400
# current:1400
# current:2500
# current:1500
# current:2600
# current:1600
# current:2700
# current:2800
# current:1700
# current:2900
# current:1800
# current:3000
# current:1900
# current:3100
# current:3200
# current:2000
# current:3300
# current:2100
# current:3400
# current:2200
# current:3500
# current:3600
# current:2300
# current:3700
# ...

# %%
def generate_test_data(test_file):
    train = pd.read_csv(test_file)

    file_name = test_file.split('/')[-1]

    num_of_lines = train.shape[0]
    print(f'{file_name} : {num_of_lines}')

    data = []
    for i in range(num_of_lines):
        if i % 100 == 0:
            print(f'current:{i}')

        tmp = train.iloc[i,1:-4].astype(int).sort_values(ascending=False).head(ITEMS_TO_TAKE)
        target = train.iloc[i, [-1]]

        line = [*tmp.index.astype(str), *tmp.values, *target]
        data.append(line)
    data = pd.DataFrame(data)
    data.columns = [f'bssid_{str(i)}' for i in range(ITEMS_TO_TAKE)] + [f'rssi_{str(i)}' for i in range(ITEMS_TO_TAKE)] + ['site_path_timestamp']
    data.to_csv(f'Unified_WiFi_{file_name}', index=False)

# %%
with Pool(num_cores) as pool:
    pool.map(generate_test_data, [t for t in test_files])
# Out:
# 5a0546857ecc773753327266_0_test.csv : 299
# current:0
# 5d27096c03f801723c31e5e0_0_test.csv : 654
# current:0
# current:100
# current:200
# current:100
# current:200
# 5c3c44b80379370013e0fd2b_0_test.csv : 26
# current:0
# 5d27075f03f801723c2e360f_0_test.csv : 47
# current:0
# current:300
# 5d2709a003f801723c3251bf_0_test.csv : 218
# current:0
# current:100
# current:400
# current:200
# 5d2709b303f801723c327472_0_test.csv : 527
# current:0
# current:500
# current:100
# current:200
# current:600
# current:300
# current:400
# current:500
# 5d27097f03f801723c320d97_0_test.csv : 303
# current:0
# current:100
# 5d2709bb03f801723c32852c_0_test.csv : 716
# current:0
# current:200
# current:100
# current:300
# current:200
# 5d27099f03f801723c32511d_0_test.csv : 49
# current:0
# current:300
# current:400
# 5d2709c303f801723c3299ee_0_test.csv : 509
# current:0
# current:500
# current:600
# current:100
# current:700
# 5da138274db8ce0c98bbd3d2_0_test.csv : 103
# current:0
# current:100
# ...

# %%
# !mv /content/Unified_WiFi_5a0546857ecc773753327266_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5c3c44b80379370013e0fd2b_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27075f03f801723c2e360f_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27096c03f801723c31e5e0_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27097f03f801723c320d97_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27099f03f801723c32511d_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709a003f801723c3251bf_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709b303f801723c327472_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709bb03f801723c32852c_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709c303f801723c3299ee_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709d403f801723c32bd39_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709e003f801723c32d896_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138274db8ce0c98bbd3d2_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da1382d4db8ce0c98bbe92e_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138314db8ce0c98bbf3a0_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138364db8ce0c98bc00f1_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da1383b4db8ce0c98bc11ab_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138754db8ce0c98bca82f_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138764db8ce0c98bcaa46_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da1389e4db8ce0c98bd0547_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138b74db8ce0c98bd4774_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da958dd46f8266d0737457b_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5dbc1d84c1eb61796cf7c010_0_train.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5dc8cea7659e181adb076a3f_0_train.csv /content/drive/MyDrive/unified_wifi_0

# %%
# !mv /content/Unified_WiFi_5a0546857ecc773753327266_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5c3c44b80379370013e0fd2b_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27075f03f801723c2e360f_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27096c03f801723c31e5e0_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27097f03f801723c320d97_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d27099f03f801723c32511d_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709a003f801723c3251bf_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709b303f801723c327472_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709bb03f801723c32852c_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709c303f801723c3299ee_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709d403f801723c32bd39_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5d2709e003f801723c32d896_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138274db8ce0c98bbd3d2_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da1382d4db8ce0c98bbe92e_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138314db8ce0c98bbf3a0_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138364db8ce0c98bc00f1_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da1383b4db8ce0c98bc11ab_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138754db8ce0c98bca82f_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138764db8ce0c98bcaa46_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da1389e4db8ce0c98bd0547_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da138b74db8ce0c98bd4774_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5da958dd46f8266d0737457b_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5dbc1d84c1eb61796cf7c010_0_test.csv /content/drive/MyDrive/unified_wifi_0
# !mv /content/Unified_WiFi_5dc8cea7659e181adb076a3f_0_test.csv /content/drive/MyDrive/unified_wifi_0

# %%
for n_files, file in enumerate(train_files):
    file = file.replace('\\', '/')
    print(file)
    if data is None:
        data = pd.read_csv(file)
    else:
        wifi_file = np.loadtxt(file, delimiter=',', dtype='str')

        wifi_file = pd.DataFrame(wifi_file)
        wifi_file = wifi_file.iloc[1:,:]
        wifi_file.columns = [f'bssid_{i}' for i in range(100)] + [f'rssi_{i}' for i in range(100)] + ['x', 'y', 'floor', 'path']
        for col in RSSI_FEATS + ['floor']:
            wifi_file[col] = wifi_file[col].astype('int')
        wifi_file['x'] = wifi_file['x'].astype('float')
        wifi_file['y'] = wifi_file['y'].astype('float')

        data = pd.concat([data, wifi_file])
        data.reset_index(drop=True, inplace=True)
# Out:
# /content/drive/MyDrive/wifi_0/5a0546857ecc773753327266_0_train.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7128eda62574> in <module>()
#       2     file = file.replace('\\', '/')
#       3     print(file)
# ----> 4     if data is None:
#       5         data = pd.read_csv(file)
#       6     else:
#
# NameError: name 'data' is not defined

# %%
a = pd.read_csv('/content/drive/MyDrive/unified_wifi_0/Unified_WiFi_5a0546857ecc773753327266_0_test.csv')
a
# Out:
#                                       bssid_0  ...                                site_path_timestamp
# 0    eebf5db207eec2f3e041f92153d789270f346821  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 1    1d1d62dcf72481cc9580fed3b724f0d27015aaf1  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 2    b26914599f6d9ba16b43975394e1eeb9d82f4bab  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 3    de53ffe7e3c71c9ed5c845fa50e0521efa5f3685  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 4    1d1d62dcf72481cc9580fed3b724f0d27015aaf1  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# ..                                        ...  ...                                                ...
# 294  46e733fa58deea74d962874847a529fb4897e655  ...  5a0546857ecc773753327266_ffcd9524c80c0fa5bb859...
# 295  46e733fa58deea74d962874847a529fb4897e655  ...  5a0546857ecc773753327266_ffcd9524c80c0fa5bb859...
# ...

# %%
b = pd.read_csv('/content/drive/MyDrive/wifi_0/5a0546857ecc773753327266_0_test.csv')
b
# Out:
#      Unnamed: 0  ...                                site_path_timestamp
# 0             4  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 1             4  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 2             4  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 3             4  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# 4             4  ...  5a0546857ecc773753327266_046cfa46be49fc1083481...
# ..          ...  ...                                                ...
# 294           4  ...  5a0546857ecc773753327266_ffcd9524c80c0fa5bb859...
# 295           4  ...  5a0546857ecc773753327266_ffcd9524c80c0fa5bb859...
# 296           4  ...  5a0546857ecc773753327266_ffcd9524c80c0fa5bb859...
# 297           4  ...  5a0546857ecc773753327266_ffcd9524c80c0fa5bb859...
# 298           4  ...  5a0546857ecc773753327266_ffcd9524c80c0fa5bb859...
#
# [299 rows x 3399 columns]
